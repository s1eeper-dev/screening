# %% [markdown]
# API 설명: https://opendart.fss.or.kr/guide/detail.do?apiGrpCd=DS001&apiId=2019018

# %%
# @title 1) 종목 기본정보 (공시코드, 종목명, 종목코드) { display-mode: "form" }

import requests
import pandas as pd
import io
import zipfile

# 여기에 당신의 Open DART API 인증키를 입력하세요.
crtfc_key = '여기에 당신의 Open DART API 인증키를 입력하세요.' # @param {type:"string"}

def get_dart_info(api_key):
    url = 'https://opendart.fss.or.kr/api/corpCode.xml'
    params = {'crtfc_key': api_key}
    try:
        results = requests.get(url, params=params)
        results.raise_for_status()  # HTTP 요청 에러가 있을 경우 예외를 발생시킵니다.

        zip_stream = io.BytesIO(results.content)
        with zipfile.ZipFile(zip_stream, 'r') as zip_ref:
            with zip_ref.open('CORPCODE.xml') as xml_file:
                xml_data = xml_file.read()

        df_dart = pd.read_xml(io.BytesIO(xml_data), xpath='//list')
        return df_dart
    except requests.RequestException as e:
        print(f"HTTP 요청 에러: {e}")
    except zipfile.BadZipFile:
        print("ZIP 파일 형식 에러")
    except Exception as e:
        print(f"기타 에러: {e}")

def process_dart_info(df_dart):
    df_temp = df_dart.copy()
    df_temp = df_temp.dropna(subset=['stock_code'])
    df_temp['modify_date'] = pd.to_datetime(df_temp['modify_date'])
    df_temp = df_temp.sort_values(by=['corp_name', 'modify_date'], ascending=[True, False])
    df_temp = df_temp.drop_duplicates(subset='corp_name', keep='first')

    df_temp = df_temp[['corp_code', 'corp_name', 'stock_code']]
    df_temp = df_temp.rename(columns={'corp_code': '공시코드', 'corp_name': '종목명', 'stock_code': '종목코드'})

    return df_temp

df_dart_info = get_dart_info(crtfc_key)
if df_dart_info is not None:
    df_dart_info_processed = process_dart_info(df_dart_info)
    df_dart_info_processed.to_csv("screening_01.csv", encoding="utf-8-sig", index=False)

# %%
# @title 2) 재무재표 분석 (시가총액, 연간 재무, 분기 재무, PER, PSR)
# @markdown <img src = "https://drive.google.com/uc?id=1uSbO7Qjaiiq0d_OsPvTOdyV8iFfgz9mi" height = 400 width = 600>
import asyncio
import aiohttp
import pandas as pd

async def fetch_page(session, url):
    async with session.get(url) as response:
        return await response.text()

async def financial_statements(session, code):
    URL = f"https://finance.naver.com/item/main.nhn?code={code}"
    html = await fetch_page(session, URL)

    # 연간 및 분기 재무 데이터 처리
    df = pd.read_html(html)[3]
    df.set_index(df.columns[0], inplace=True)
    df.index.rename('주요재무정보', inplace=True)
    df.columns = df.columns.droplevel(2)
    annual_financial = df.xs('최근 연간 실적', axis=1)
    quarter_financial = df.xs('최근 분기 실적', axis=1)

    # 시가총액 데이터 처리
    df = pd.read_html(html)[5]
    market_capitalization = df.loc[df[0] == '시가총액', 1].values[0]
    market_capitalization = int(market_capitalization.replace(' ','').replace(',', '').replace('억원', '').replace('조', ''))

    return annual_financial, quarter_financial, market_capitalization

def check_performance(df, target_col, target_rows):
    df = df.loc[target_rows]
    # @markdown 입력값 이상 (ex: 매출액, 영업이익, 당기순이익 0원 이상일 때에만 ⭕)
    매출액 = 0 # @param {type:"number"}
    영업이익 = 0 # @param {type:"number"}
    당기순이익 = 0 # @param {type:"number"}

    # @markdown 입력값 이하 (ex: 부채비율이 200 이하일 때에만 ⭕)
    부채비율 = 200 # @param {type:"number"}

    if df[target_col].isnull().values.any():
        return '❌'
    try:
        if float(df[target_col]['매출액']) <= 매출액: return '❌'
        if float(df[target_col]['영업이익']) <= 영업이익: return '❌'
        if float(df[target_col]['당기순이익']) <= 당기순이익: return '❌'
        if float(df[target_col]['부채비율']) >= 부채비율: return '❌'
    except ValueError:
        return "❌"
    return '⭕'

async def process_stock_code(session, df_dart_info, code, semaphore):
    async with semaphore:
        TARGET_ROWS = ['매출액', '당기순이익', '영업이익', '부채비율']

        try:
            df_an, df_qu, market_capitalization = await financial_statements(session, code)
        except Exception as e:
            #print(f"Error processing {code}: {e}")
            return

        df_dart_info.loc[df_dart_info['종목코드'] == code, f'시가총액'] = market_capitalization

        df_qu_results = []
        for idx, col in enumerate(df_qu.columns[:-1]):
            df_qu_result = check_performance(df_qu, col, TARGET_ROWS)
            df_dart_info.loc[df_dart_info['종목코드'] == code, f'q_{idx}'] = df_qu_result
            df_qu_results.append(df_qu_result)

        df_an_results = []
        for idx, col in enumerate(df_an.columns[:-1]):
            df_an_result = check_performance(df_an, col, TARGET_ROWS)
            df_dart_info.loc[df_dart_info['종목코드'] == code, f'y_{idx}'] = df_an_result
            df_an_results.append(df_an_result)


        print('{:<7} {:<14} \t시가총액(억원): {:<10} \t연간 실적: {:<3} {:<3} {:<3} \t분기 실적: {:<3} {:<3} {:<3} {:<3} {:<3}'.format(
                code,
                df_dart_info[df_dart_info['종목코드'] == code]['종목명'].values[0],
                market_capitalization,
                df_an_results[0], df_an_results[1], df_an_results[2],
                df_qu_results[0], df_qu_results[1], df_qu_results[2], df_qu_results[3], df_qu_results[4]
        ))

        if df_an_result == '⭕':
            market_capitalization = df_dart_info[df_dart_info['종목코드'] == code]['시가총액'].values[0].astype(float)
            net_income = float(df_an[col]['당기순이익'])
            revenue = float(df_an[col]['매출액'])

            df_dart_info.loc[df_dart_info['종목코드'] == code, 'PER'] = round(market_capitalization / net_income, 2)
            df_dart_info.loc[df_dart_info['종목코드'] == code, 'PSR'] = round(market_capitalization / revenue, 2)

async def main(df):
    semaphore = asyncio.Semaphore(1500)
    async with aiohttp.ClientSession() as session:
        tasks = [process_stock_code(session, df, code, semaphore) for code in df['종목코드']]
        await asyncio.gather(*tasks)

    return df

with open("screening_01.csv") as file :
    df_dart_info = pd.read_csv(file)

df_dart_info = df_dart_info.dropna(subset=['종목코드'])
df_dart_info['종목코드'] = df_dart_info['종목코드'].astype(str).str.split('.').str[0].str.zfill(6)

df_financial_statements = await main(df_dart_info)
df_financial_statements = df_financial_statements.dropna(subset=['시가총액'])
df_financial_statements.to_csv("screening_02.csv", encoding="utf-8-sig", index=False)
# Out:
# 001500  현대차증권          	시가총액(억원): 3032       	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 057050  현대홈쇼핑          	시가총액(억원): 5568       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 008770  호텔신라           	시가총액(억원): 23745      	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 127980  화인써키트          	시가총액(억원): 1036       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 126640  화신정공           	시가총액(억원): 591        	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 353190  휴럼             	시가총액(억원): 438        	연간 실적: ❌   ❌   ❌   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 000850  화천기공           	시가총액(억원): 728        	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ❌
# 039610  화성밸브           	시가총액(억원): 578        	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 084110  휴온스글로벌         	시가총액(억원): 3136       	연간 실적: ⭕   ⭕   ❌   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 037440  희림             	시가총액(억원): 987        	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 028080  휴맥스홀딩스         	시가총액(억원): 552        	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 460930  현대힘스           	시가총액(억원): 6394       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 192410  휴림네트웍스         	시가총액(억원): 500        	연간 실적: ❌   ⭕   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 238490  힘스             	시가총액(억원): 723        	연간 실적: ⭕   ❌   ❌   	분기 실적: ❌   ❌   ❌   ⭕   ⭕
# 061250  화일약품           	시가총액(억원): 1210       	연간 실적: ⭕   ⭕   ❌   	분기 실적: ❌   ❌   ⭕   ⭕   ❌
# 090710  휴림로봇           	시가총액(억원): 2159       	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 005010  휴스틸            	시가총액(억원): 2871       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 005440  현대지에프홀딩스       	시가총액(억원): 7444       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ❌   ❌   ⭕   ⭕
# 013520  화승코퍼레이션        	시가총액(억원): 1096       	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 000540  흥국화재           	시가총액(억원): 3726       	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 004560  현대비앤지스틸        	시가총액(억원): 2876       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 079980  휴비스            	시가총액(억원): 1447       	연간 실적: ⭕   ⭕   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 263920  휴엠앤씨           	시가총액(억원): 562        	연간 실적: ❌   ❌   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 298050  효성첨단소재         	시가총액(억원): 14605      	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 138360  협진             	시가총액(억원): 315        	연간 실적: ❌   ⭕   ❌   	분기 실적: ❌   ⭕   ❌   ❌   ❌
# 200670  휴메딕스           	시가총액(억원): 3279       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 004310  현대약품           	시가총액(억원): 1262       	연간 실적: ⭕   ❌   ❌   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 081660  휠라홀딩스          	시가총액(억원): 24240      	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 093370  후성             	시가총액(억원): 8473       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ❌   ❌   ❌   ❌
# 241590  화승엔터프라이즈       	시가총액(억원): 4690       	연간 실적: ⭕   ❌   ❌   	분기 실적: ⭕   ❌   ❌   ❌   ❌
# 145020  휴젤             	시가총액(억원): 21793      	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 060560  홈센타홀딩스         	시가총액(억원): 1471       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 094280  효성 ITX         	시가총액(억원): 1441       	연간 실적: ❌   ⭕   ⭕   	분기 실적: ❌   ⭕   ⭕   ⭕   ⭕
# 065510  휴비츠            	시가총액(억원): 2204       	연간 실적: ❌   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 004800  효성             	시가총액(억원): 13148      	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ❌   ❌   ❌   ⭕   ⭕
# 298020  효성티앤씨          	시가총액(억원): 13091      	연간 실적: ❌   ⭕   ⭕   	분기 실적: ❌   ❌   ⭕   ⭕   ⭕
# 189980  흥국에프엔비         	시가총액(억원): 895        	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 003010  혜인             	시가총액(억원): 739        	연간 실적: ⭕   ⭕   ❌   	분기 실적: ❌   ❌   ❌   ⭕   ⭕
# 298040  효성중공업          	시가총액(억원): 17353      	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 003280  흥아해운           	시가총액(억원): 7333       	연간 실적: ❌   ❌   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 092300  현우산업           	시가총액(억원): 822        	연간 실적: ⭕   ❌   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 010690  화신             	시가총액(억원): 4288       	연간 실적: ❌   ❌   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 078590  휴림에이텍          	시가총액(억원): 734        	연간 실적: ❌   ❌   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 032560  황금에스티          	시가총액(억원): 1244       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 307950  현대오토에버         	시가총액(억원): 42781      	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 001450  현대해상           	시가총액(억원): 3575       	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 006060  화승인더스트리        	시가총액(억원): 1867       	연간 실적: ⭕   ❌   ⭕   	분기 실적: ⭕   ❌   ❌   ❌   ❌
# 064240  홈캐스트           	시가총액(억원): 964        	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 011760  현대코퍼레이션        	시가총액(억원): 2553       	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 243070  휴온스            	시가총액(억원): 4438       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 215090  휴센텍            	시가총액(억원): 1208       	연간 실적: ❌   ❌   ❌   	분기 실적: ⭕   ⭕   ❌   ❌   ❌
# 005380  현대자동차          	시가총액(억원): 511906     	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 126560  현대퓨처넷          	시가총액(억원): 4083       	연간 실적: ❌   ⭕   ❌   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 039010  현대에이치티         	시가총액(억원): 604        	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ❌   ⭕   ❌   ❌
# 290270  휴네시온           	시가총액(억원): 418        	연간 실적: ⭕   ⭕   ❌   	분기 실적: ⭕   ❌   ❌   ❌   ⭕
# 011080  형지I&C          	시가총액(억원): 219        	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 010240  흥국             	시가총액(억원): 707        	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 005870  휴니드테크놀러지스      	시가총액(억원): 971        	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ❌   ❌   ⭕
# 378850  화승알앤에이         	시가총액(억원): 839        	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 024060  흥구석유           	시가총액(억원): 1666       	연간 실적: ❌   ❌   ⭕   	분기 실적: ⭕   ⭕   ⭕   ❌   ❌
# 002460  화성산업           	시가총액(억원): 1121       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 090850  현대이지웰          	시가총액(억원): 1373       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 097870  효성오앤비          	시가총액(억원): 672        	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ❌   ⭕   ⭕   ❌   ⭕
# 133820  화인베스틸          	시가총액(억원): 311        	연간 실적: ❌   ⭕   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 205470  휴마시스           	시가총액(억원): 2368       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 016580  환인제약           	시가총액(억원): 2827       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 011210  현대위아           	시가총액(억원): 16535      	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ❌   ❌   ⭕   ⭕   ⭕
# 017800  현대엘리베이터        	시가총액(억원): 16145      	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ❌   ⭕   ⭕   ⭕   ⭕
# 115160  휴맥스            	시가총액(억원): 1367       	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 004020  현대제철           	시가총액(억원): 47373      	연간 실적: ❌   ⭕   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 111110  호전실업           	시가총액(억원): 751        	연간 실적: ❌   ⭕   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕
# 010660  화천기계           	시가총액(억원): 861        	연간 실적: ❌   ⭕   ⭕   	분기 실적: ❌   ❌   ❌   ⭕   ❌
# 093240  형지엘리트          	시가총액(억원): 422        	연간 실적: ❌   ⭕   ⭕   	분기 실적: ❌   ⭕   ⭕   ⭕   ❌
# 227840  현대코퍼레이션홀딩스     	시가총액(억원): 1010       	연간 실적: ⭕   ⭕   ⭕   	분기 실적: ⭕   ⭕   ⭕   ⭕   ⭕
# 298000  효성화학           	시가총액(억원): 2764       	연간 실적: ❌   ❌   ❌   	분기 실적: ❌   ❌   ❌   ❌   ❌
# 041440  현대에버다임         	시가총액(억원): 1181       	연간 실적: ❌   ❌   ⭕   	분기 실적: ⭕   ❌   ⭕   ⭕   ⭕

# %%
# @title 3) 공시 분석

import asyncio
import aiohttp
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta
import numpy as np
import requests

with open("screening_02.csv") as file :
    df_financial_statements = pd.read_csv(file)

# 공시코드 열의 값들을 문자열로 변환하고 8자리로 맞춤
df_financial_statements['공시코드'] = df_financial_statements['공시코드'].astype(str).str.zfill(8)

# 공시기간 설정
today = datetime.now()
end_de = today.strftime("%Y%m%d")
bgn_de = (today - relativedelta(years=5)).strftime("%Y%m%d")

crtfc_key = '여기에 당신의 Open DART API 인증키를 입력하세요.' # @param {type:"string"}

def check_disclosure(df):
    위험공시 = ['유상증자', '감자', '단기차입금', '전환사채', '전환청구권', '검토의견부적정', '파생상품거래손실', '횡령', '영업정지'] # @param {type:"string"}

    for report in df['report_nm']:
        contain = any(item in report for item in 위험공시)

        if contain:
            disclosure_date = df[df['report_nm'] == report]['rcept_dt'].values[0]
            return f'{disclosure_date}: {report}'

    return "⭕"

async def fetch_page(session, url, params, max_retries=5):
    for attempt in range(max_retries):
        try:
            async with session.get(url, params=params) as response:
                return await response.json()
        except aiohttp.ClientError:
            if attempt < max_retries - 1:
                await asyncio.sleep(3 ** attempt)  # 지수적 백오프
            else:
                raise

async def process_page(session, url, params):
    json = await fetch_page(session, url, params)
    df_temp = pd.DataFrame(json.get('list')).dropna(how='all')

    return df_temp

async def get_total_page(session, url, params):
    json = await fetch_page(session, url, params)
    total_page = json.get('total_page')

    return total_page

async def fetch_disclosure(code, semaphore):
    async with semaphore, aiohttp.ClientSession() as session:
        df_disclosure = pd.DataFrame()
        url = 'https://opendart.fss.or.kr/api/list.json'
        params = {
            'crtfc_key': crtfc_key,
            'corp_code': code,
            'bgn_de': bgn_de,
            'end_de': end_de,
            'page_no': 0,
            'page_count': 100,
            'last_reprt_at': 'Y',
        }

        try:
            total_page = await get_total_page(session,url,params)
            tasks = [process_page(session, url, {**params, 'page_no': page}) for page in range(1, total_page+1)]
            pages = await asyncio.gather(*tasks)
        except Exception as e:
            print(f"Error processing {code}: {e}")
            return code, "Error"

        for df_temp in pages:
            if df_temp is not None:
                df_disclosure = pd.concat([df_disclosure, df_temp], axis=0)

        disclosure_value = check_disclosure(df_disclosure)

        print('{:<7} {:<14} \t {:<100}'.format(
            code,
            df_financial_statements[df_financial_statements['공시코드'] == code]['종목명'].values[0],
            disclosure_value
        ))
        return code, disclosure_value

async def main():
    semaphore = asyncio.Semaphore(5)
    tasks = [fetch_disclosure(code, semaphore) for code in df_financial_statements['공시코드']]
    results = await asyncio.gather(*tasks)

    for code, disclosure_value in results:
        df_financial_statements.loc[df_financial_statements['공시코드'] == code, '공시'] = disclosure_value

    return df_financial_statements

df_disclosure = await main()
df_disclosure.to_csv("screening_03.csv", encoding="utf-8-sig", index=False)
# Out:
# 01203808 AP시스템          	 20190611: 단기차입금증가결정
# 00365387 AJ네트웍스         	 20230203: 유상증자결정(종속회사의주요경영사항)
# 00378363 3S             	 20221115: [기재정정]주요사항보고서(유상증자결정)
# 00296078 APS            	 20211223: 유상증자결정(종속회사의주요경영사항)
# 00125080 AK홀딩스          	 20230925: 주요사항보고서(유상증자결정)(자회사의 주요경영사항)
# 00874803 AP위성           	 ⭕
# 00656021 BF랩스           	 20240202: 전환청구권행사
# 00219097 BGF            	 20230814: 파생상품거래손실발생(자회사의 주요경영사항)
# 00599595 BGF에코머티리얼즈     	 20230814: 파생상품거래손실발생
# 01263022 BGF리테일         	 ⭕
# 00858364 BNK금융지주        	 20231221: [기재정정]횡령ㆍ배임혐의발생(자회사의 주요경영사항)
# 00122579 BYC            	 ⭕
# 00407814 CG인바이츠         	 20230918: [기재정정]주요사항보고서(유상증자결정)
# 00151605 CBI            	 20240215: [기재정정]주요사항보고서(전환사채권발행결정)
# 00148540 CJ             	 20240105: 단기차입금증가결정(자회사의 주요경영사항)
# 00303873 CJ CGV         	 20240105: 단기차입금증가결정
# 00265324 CJ ENM         	 20220218: 유상증자결정(자율공시)(종속회사의주요경영사항)
# 01071041 CJ 바이오사이언스     	 20230904: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00113410 CJ대한통운         	 20231214: 단기차입금증가결정
# 00129013 CJ씨푸드          	 20231123: 단기차입금증가결정
# 00635134 CJ제일제당         	 20211220: 감자결정(종속회사의주요경영사항)
# 00127954 CJ프레시웨이        	 20191106: 유상증자결정(종속회사의주요경영사항)
# 00380429 CMG제약          	 20230328: 주요사항보고서(전환사채권발행결정)
# 00149266 CNH            	 ⭕
# 00318662 CNT85          	 20230831: 전환청구권행사(제23회차)
# 01731453 DB금융스팩11호      	 ⭕
# 00303703 CS             	 20240102: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00406037 CSA 코스믹        	 20230712: 증권발행결과(자율공시)(제3자배정 유상증자)
# 00149026 CS홀딩스          	 ⭕
# 00163345 DB             	 20231228: 단기차입금증가결정
# 00115694 DB금융투자         	 20230315: 단기차입금증가결정
# 00159102 DB손해보험         	 ⭕
# 00878915 DGB금융지주        	 20240111: 횡령ㆍ배임사실확인(자회사의 주요경영사항)
# 00160843 DB하이텍          	 ⭕
# 00367695 DGP            	 20231227: [기재정정]주요사항보고서(유상증자결정)
# 00110583 DH오토웨어         	 20220705: 주요사항보고서(유상증자결정)
# 00128971 DL건설           	 ⭕
# 00109693 DL             	 20221128: [기재정정]유상증자결정(종속회사의주요경영사항)
# 01524093 DL이앤씨          	 ⭕
# 00361594 DMS            	 20201116: 전환청구권행사
# 00118266 DRB동일          	 ⭕
# 00110608 DSR            	 ⭕
# 00151298 DSR제강          	 ⭕
# 00116949 DN오토모티브        	 20231128: 유상증자결정(종속회사의주요경영사항)
# 01109715 DSC인베스트먼트      	 20201211: [기재정정]전환청구권행사
# 00108612 DS단석           	 ⭕
# 00995993 DXVX           	 20230614: [기재정정]주요사항보고서(유상증자결정)
# 00165583 E1             	 ⭕
# 01182550 EDGC           	 20240130: 주요사항보고서(유상증자결정)
# 00261054 EG             	 20230515: 단기차입금증가결정
# 00175623 ES큐브           	 20230821: 횡령ㆍ배임혐의진행사항
# 01568413 F&F            	 20210726: [기재정정]단기차입금증가결정
# 00491938 GH신소재          	 20210916: 유상증자또는주식관련사채등의청약결과(자율공시)
# 00126487 F&F 홀딩스        	 20210819: 유상증자또는주식관련사채등의발행결과(자율공시)
# 01061497 FSN            	 20240112: 주요사항보고서(전환사채권발행결정)
# 00557508 GKL            	 ⭕
# 01170962 GRT            	 20230921: 유상증자결정(자회사의 주요경영사항)
# 00500254 GS             	 20210217: 단기차입금증가결정(자회사의 주요경영사항)
# 00540863 GST            	 ⭕
# 00120030 GS건설           	 20240201: 주요사항보고서(영업정지)
# 00309460 HB인베스트먼트       	 ⭕
# 00138190 GS글로벌          	 ⭕
# 00140177 GS리테일          	 20191223: [기재정정]유상증자결정(종속회사의주요경영사항)
# 00523936 HB솔루션          	 20240112: 전환청구권행사
# 00255275 HB테크놀러지        	 20230927: 전환청구권행사
# 00350312 HDC랩스          	 ⭕
# 00164636 HDC            	 20220721: 단기차입금증가결정(자회사의 주요경영사항)
# 00357935 HDC현대EP        	 20211210: 유상증자결정(종속회사의주요경영사항)
# 01310269 HDC현대산업개발      	 20220721: 단기차입금증가결정
# 00164830 HD한국조선해양       	 20220308: [기재정정]주요사항보고서(유상증자결정)
# 01205709 HD현대           	 20220308: [기재정정]주요사항보고서(유상증자결정)(자회사의 주요경영사항)
# 01205842 HD현대건설기계       	 20240206: 주요사항보고서(감자결정)
# 01199550 HD현대에너지솔루션     	 20191010: 유상증자결정
# 00344287 HD현대인프라코어      	 20211216: 유상증자또는주식관련사채등의발행결과(자율공시)
# 01205851 HD현대일렉트릭       	 20231025: 파생상품거래손실발생
# 00633835 HJ중공업          	 20190419: [기재정정]주요사항보고서(감자결정)
# 01012066 HK이노엔          	 20211001: 단기차입금증가결정
# 01390344 HD현대중공업        	 20210906: [기재정정]주요사항보고서(유상증자결정)
# 00365590 HLB생명과학        	 20231107: 전환사채(해외전환사채포함)발행후만기전사채취득
# 01189438 HLB바이오스텝       	 20240219: 전환청구권행사
# 00169048 HLB글로벌         	 20231031: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00155586 HLB이노베이션       	 20240215: 전환청구권행사              (제2회차)
# 00336817 HLB제약          	 20240130: 전환청구권행사
# 00552859 HLB테라퓨틱스       	 20240207: [기재정정]전환청구권행사              (제14회차)
# 01042775 HL만도           	 ⭕
# 00161116 HL D&I         	 20220303: [기재정정]주요사항보고서(유상증자결정)
# 01288827 HPSP           	 ⭕
# 00230911 HRS            	 ⭕
# 00172079 HLB파나진         	 20240208: 파생상품거래손실발생
# 00361008 HSD엔진          	 20240208: [기재정정]주요사항보고서(유상증자결정)
# 00299002 HL홀딩스          	 20230307: 단기차입금증가결정
# 01675421 IBKS제20호스팩     	 ⭕
# 00140168 HS애드           	 ⭕
# 01682740 IBKS제21호스팩     	 ⭕
# 01701328 IBKS제22호스팩     	 ⭕
# 00572905 ISC            	 20230927: [기재정정]주요사항보고서(유상증자결정)
# 00627029 ITX-AI         	 20231019: [기재정정]전환청구권행사(제4회차)
# 00980122 JB금융지주         	 20230725: 단기차입금증가결정(자회사의 주요경영사항)
# 01041828 JTC            	 20240122: 감자완료
# 00225706 JW생명과학         	 ⭕
# 00110431 JW신약           	 20201005: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00149947 JW중외제약         	 20221028: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00632304 JW홀딩스          	 20221020: 주요사항보고서(유상증자결정)(자회사의 주요경영사항)
# 00258689 JYP Ent.       	 ⭕
# 00876166 KBG            	 20230522: 전환청구권행사(제3회차)
# 00158024 KBI메탈          	 20231127: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00688996 KB금융           	 20190322: 단기차입금증가결정(자회사의 주요경영사항)
# 00157539 KB오토시스         	 ⭕
# 01724709 KB제25호스팩       	 ⭕
# 01766167 KB제26호스팩       	 ⭕
# 00265041 KCI            	 ⭕
# 00105466 KCC건설          	 20220908: 단기차입금증가결정
# 00164645 HMM            	 20210813: 파생상품거래손실발생
# 00159971 KC그린홀딩스        	 20231215: 단기차입금증가결정(자회사의 주요경영사항)
# 00797364 KC코트렐          	 20231215: 단기차입금증가결정
# 00589127 KEC            	 20230629: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00111218 KD             	 20231212: [첨부정정]주요사항보고서(전환사채권발행결정)
# 00366137 KG ETS         	 20221212: 유상증자결정(종속회사의주요경영사항)
# 00405278 KG모빌리언스        	 20230206: 단기차입금증가결정
# 00138242 KG모빌리티         	 20231205: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00115676 KG스틸           	 20190830: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00264547 KG이니시스         	 20201023: 유상증자결정(종속회사의주요경영사항)
# 00199252 HLB            	 20231204: 전환사채(해외전환사채포함)발행후만기전사채취득(제36회차)
# 00101220 KG케미칼          	 20230728: [기재정정]주요사항보고서(감자결정)
# 00125965 KH 전자          	 20240131: 전환청구권행사(제10회차)
# 01097906 KH 건설          	 20240129: 전환청구권행사(제12회차)
# 00193009 KH 필룩스         	 20240131: [기재정정]주요사항보고서(감자결정)
# 00378628 KH바텍           	 20200818: 전환사채(해외전환사채포함)발행후만기전사채취득(제2회차)
# 00208134 KNN            	 ⭕
# 00108746 KIB플러그에너지      	 20230904: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00159740 KISCO홀딩스       	 20221123: 영업정지(종속회사의주요경영사항)
# 00191472 KPX케미칼         	 ⭕
# 00587466 KPX홀딩스         	 ⭕
# 00112378 KR모터스          	 20240126: [기재정정]주요사항보고서(유상증자결정)
# 00160232 KSS해운          	 ⭕
# 00372882 KTcs           	 ⭕
# 00372873 KTis           	 20210601: [기재정정]단기차입금증가결정
# 00657987 KX             	 20211217: 소송등의판결ㆍ결정(전환사채등 발행무효확인)
# 00527011 LB루셈           	 ⭕
# 00412348 LB세미콘          	 20210607: [기재정정]유상증자결정(종속회사의주요경영사항)
# 00231901 LB인베스트먼트       	 ⭕
# 00276834 KX하이텍          	 20230227: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00593032 LF             	 20220701: 유상증자결정(종속회사의주요경영사항)
# 00120021 LG             	 20210412: [첨부정정]주요사항보고서(영업정지)(자회사의 주요경영사항)
# 00105873 LG디스플레이        	 20240124: [기재정정]주요사항보고서(유상증자결정)
# 01515323 LG에너지솔루션       	 20231005: 유상증자결정(종속회사의주요경영사항)
# 00356370 LG생활건강         	 20200129: 유상증자결정(종속회사의주요경영사항)
# 00231363 LG유플러스         	 ⭕
# 00105961 LG이노텍          	 20221124: 단기차입금증가결정
# 00222532 LG헬로비전         	 ⭕
# 00401731 LG전자           	 20220223: 영업정지(자율공시)
# 00356361 LG화학           	 20231005: 유상증자결정(종속회사의주요경영사항)
# 00503668 LIG넥스원         	 20221028: 파생상품거래손실발생
# 01528141 LS머트리얼즈        	 20231106: [기재정정]유상증자결정
# 00105952 LS             	 20231114: 파생상품거래손실발생(자회사의 주요경영사항)
# 00104698 LS네트웍스         	 20230922: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00225742 LS마린솔루션        	 20221130: 증권발행결과(자율공시)(제3자배정 유상증자)
# 01093007 LS에코에너지        	 20220531: 단기차입금증가결정(자회사의 주요경영사항)
# 00525934 LX세미콘          	 ⭕
# 00120076 LX인터내셔널        	 ⭕
# 01562589 LX홀딩스          	 20221011: 단기차입금증가결정(자회사의 주요경영사항)
# 00759513 LX하우시스         	 20221011: 단기차입금증가결정
# 00121534 MH에탄올          	 ⭕
# 00974927 NEW            	 20230322: [기재정정]주요사항보고서(전환사채권발행결정)
# 00445841 MDS테크          	 20230901: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00215976 MIT            	 20240207: 증권발행결과(자율공시)              (제28회차 전환사채)
# 00266961 NAVER          	 20230503: 유상증자결정(종속회사의주요경영사항)
# 00363927 NE능률           	 20200901: 전환청구권행사(제1회차)
# 00357740 NHN KCP        	 ⭕
# 00645089 NHN벅스          	 ⭕
# 00158325 NICE평가정보       	 ⭕
# 00158316 NICE           	 ⭕
# 00120182 NH투자증권         	 20220302: 주요사항보고서(유상증자결정)
# 00116301 NI스틸           	 ⭕
# 01760738 OCI            	 20231026: 특수관계인의유상증자참여
# 01037542 NPX            	 20240205: [기재정정]주요사항보고서(전환사채권발행결정)
# 00148896 OCI홀딩스         	 20240112: 주요사항보고서(유상증자결정)
# 00133557 PN풍년           	 ⭕
# 00767460 PI첨단소재         	 ⭕
# 00155319 POSCO홀딩스       	 20210202: 영업정지(종속회사의주요경영사항)
# 01078178 RFHIC          	 20210708: 유상증자또는주식관련사채등의청약결과(자율공시)
# 00580667 S&K폴리텍         	 ⭕
# 01343665 RF머트리얼즈        	 20220615: 주요사항보고서(전환사채권발행결정)
# 01082418 SAMG엔터         	 20230811: 주요사항보고서(전환사채권발행결정)
# 00138279 S-Oil          	 ⭕
# 00156910 SBI인베스트먼트      	 ⭕
# 00938688 SBI핀테크솔루션즈     	 20230913: 단기차입금증가결정
# 00130772 SBS            	 ⭕
# 00653103 SBW생명과학        	 20240215: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00301246 SFA반도체         	 20200214: [기재정정]전환청구권행사
# 00260745 SCI평가정보        	 ⭕
# 00574611 SDN            	 20230926: 주요사항보고서(전환사채권발행결정)
# 00963976 SG             	 20240206: 전환청구권행사
# 00264714 SG&G           	 ⭕
# 00351579 SGA            	 20240126: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00988364 SGA솔루션즈        	 20240202: [기재정정]주요사항보고서(유상증자결정)
# 00125150 SGC에너지         	 20231023: [기재정정]영업정지(종속회사의주요경영사항)
# 00152039 SG글로벌          	 20210205: 유상증자결정(종속회사의주요경영사항)
# 00141246 SGC이테크건설       	 20240131: 주요사항보고서(유상증자결정)
# 00133511 SG세계물산         	 ⭕
# 00137809 SHD            	 20200130: 횡령ㆍ배임혐의발생
# 00136457 SH에너지화학        	 ⭕
# 00138260 SIMPAC         	 ⭕
# 00181712 SK             	 20230907: [기재정정]주요사항보고서(유상증자결정)(자회사의 주요경영사항)
# 00139889 SKC            	 20240118: 유상증자결정(종속회사의주요경영사항)
# 00144164 SK가스           	 20220415: 유상증자결정(종속회사의주요경영사항)
# 00131780 SK네트웍스         	 20220128: 횡령ㆍ배임사실확인
# 00131832 SK디스커버리        	 20231207: 단기차입금증가결정(자회사의 주요경영사항)
# 00508344 SK디앤디          	 20231207: 단기차입금증가결정
# 01596425 SK스퀘어          	 20230629: 유상증자결정(자회사의 주요경영사항)
# 01386916 SK아이이테크놀로지     	 20220907: 유상증자결정(종속회사의주요경영사항)
# 01319899 SK바이오사이언스      	 20210308: [기재정정]주요사항보고서(유상증자결정)
# 00480367 SK오션플랜트        	 20220902: 전환청구권행사(제7회차)
# 01744703 SK증권제10호스팩     	 ⭕
# 00131850 SK증권           	 20221221: [기재정정]유상증자결정(종속회사의주요경영사항)
# 01725577 SK증권제9호스팩      	 ⭕
# 00631518 SK이노베이션        	 20240220: 유상증자결정(종속회사의주요경영사항)
# 00164779 SK하이닉스         	 20230412: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00159023 SK텔레콤          	 ⭕
# 00185046 SM C&C         	 ⭕
# 00134477 SNT다이내믹스       	 ⭕
# 00367604 SM Life Design 	 20190603: 증권발행결과(자율공시)(제3자배정 유상증자)
# 00398792 SNT모티브         	 ⭕
# 00225159 SNT홀딩스         	 ⭕
# 00648721 SNT에너지         	 ⭕
# 00125530 SPC삼립          	 ⭕
# 00138297 STX            	 20231218: 유상증자또는주식관련사채등의발행결과(자율공시)
# 01784394 STX그린로지스       	 20231229: [기재정정]주요사항보고서(전환사채권발행결정)
# 00480455 STX엔진          	 20230222: [기재정정]주요사항보고서(전환사채권발행결정)
# 00406046 STX중공업         	 20230731: 주요사항보고서(유상증자결정)
# 00132211 SUN&L          	 ⭕
# 00599151 SV인베스트먼트       	 20230926: 주요사항보고서(전환사채권발행결정)
# 00117300 TCC스틸          	 20230512: 파생상품거래손실발생
# 00519252 THE E&M        	 20240207: [기재정정]기타경영사항(자율공시)              (제13회차, 제14회차, 제15회차 사모 전환사채 만기전 취득 후 재매각의 건)
# 01671197 SK증권제8호스팩      	 ⭕
# 00945208 THE MIDONG     	 20231123: [기재정정]주요사항보고서(유상증자결정)
# 00201733 TJ미디어          	 20200611: 단기차입금증가결정
# 00140061 TKG애강          	 ⭕
# 00108649 TPC            	 20221021: 전환청구권행사
# 00778235 TS인베스트먼트       	 20231229: 전환사채(해외전환사채포함)발행후만기전사채취득
# 01353024 TS트릴리온         	 20231227: 증권발행결과(자율공시)(제3자배정 유상증자-소액공모)
# 00117230 TYM            	 20210930: 감자결정(종속회사의주요경영사항)
# 00307222 YBM넷           	 ⭕
# 00142865 WISCOM         	 ⭕
# 00249247 YG PLUS        	 20210205: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00296263 YW             	 ⭕
# 00370006 iMBC           	 20190731: 주요사항보고서(영업정지)
# 00200275 YTN            	 ⭕
# 01267170 SK케미칼          	 20230306: 유상증자결정(종속회사의주요경영사항)
# 00506294 가비아            	 ⭕
# 01364747 가온칩스           	 ⭕
# 00104768 가온전선           	 20231221: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00441304 가온그룹           	 20210602: 주요사항보고서(전환사채권발행결정)
# 00261009 감성코퍼레이션        	 20230426: 주요사항보고서(제3자의전환사채매수선택권행사)
# 00100939 강남제비스코         	 ⭕
# 01025644 강스템바이오텍        	 20231106: 유상증자또는주식관련사채등의청약결과(자율공시)
# 00255619 강원랜드           	 ⭕
# 00100601 강원에너지          	 20230811: 파생상품거래손실발생
# 00587457 갤럭시아머니트리       	 20230727: 단기차입금증가결정
# 00129554 갤럭시아에스엠        	 20221031: 단기차입금증가결정
# 00206039 경남스틸           	 20220106: 전환청구권행사
# 00101433 경농             	 20221110: [기재정정]단기차입금증가결정
# 00307028 경남제약           	 20230919: [기재정정]주요사항보고서(전환사채권발행결정)
# 01208885 경동도시가스         	 ⭕
# 00101488 경동나비엔          	 ⭕
# 00143527 경동인베스트         	 ⭕
# 00101549 경동제약           	 20201104: 전환청구권행사
# 00101664 경보제약           	 ⭕
# 00101628 경방             	 20200806: [기재정정]유상증자결정(종속회사의주요경영사항)
# 00102113 경인양행           	 ⭕
# 00102353 경창산업           	 ⭕
# 00102140 경인전자           	 ⭕
# 00102432 계룡건설산업         	 20200212: 감자결정(종속회사의주요경영사항)
# 00102618 계양전기           	 20230609: 횡령ㆍ배임사실확인
# 00102751 고려산업           	 20220715: 단기차입금증가결정
# 00336297 고려신용정보         	 ⭕
# 01032583 고려시멘트          	 ⭕
# 00102858 고려아연           	 20230913: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00103015 고려제약           	 20230222: 주요사항보고서(영업정지)
# 00103006 고려제강           	 ⭕
# 01399071 고바이오랩          	 20220406: 증권발행결과(자율공시)(제3자배정 유상증자)
# 01416235 고스트스튜디오        	 ⭕
# 00579999 고영             	 ⭕
# 01168143 골든센츄리          	 20230718: 기타주요경영사항(제5회차 전환사채 발행결정 철회)
# 00249502 골드앤에스          	 20231226: 전환사채(해외전환사채포함)발행후만기전사채취득(제18회차)
# 01067516 골프존            	 ⭕
# 00674498 골프존뉴딘홀딩스       	 20221013: 기타주요경영사항(자회사의 주요경영사항)(유상증자결정 철회)
# 01307335 공구우먼           	 ⭕
# 00103592 광동제약           	 20230921: [첨부추가]주요사항보고서(영업정지)
# 00103635 광림             	 20231226: 전환사채(해외전환사채포함)발행후만기전사채취득(제8회차)
# 00103662 광명전기           	 ⭕
# 00152729 광전자            	 ⭕
# 00186452 광무             	 20231206: 전환사채(해외전환사채포함)발행후만기전사채취득(제39회차)
# 00104120 광진실업           	 20230508: 단기차입금증가결정
# 00220561 광주신세계          	 20231127: [기재정정]주요사항보고서(영업정지)
# 01582228 교보11호스팩        	 ⭕
# 01620713 교보12호스팩        	 ⭕
# 01677678 교보13호스팩        	 ⭕
# 01760640 교보14호스팩        	 ⭕
# 00453284 교촌에프앤비         	 20220930: 단기차입금증가결정
# 00202060 구영테크           	 20231222: 전환청구권행사
# 00104388 국도화학           	 20210820: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00113359 교보증권           	 20230822: 특수관계인의유상증자참여
# 00168331 국동             	 20230518: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00104519 국보             	 20240214: 주요사항보고서(유상증자결정)
# 00253985 국보디자인          	 ⭕
# 00256715 국순당            	 ⭕
# 00104537 국영지앤엠          	 ⭕
# 00203847 국일신동           	 ⭕
# 01329957 국전약품           	 20220914: 주요사항보고서(전환사채권발행결정)
# 00104573 국일제지           	 20240208: 감자완료              (2차)
# 00104722 국제약품           	 ⭕
# 00244561 그래디언트          	 ⭕
# 00671978 그리티            	 20200504: 전환사채(해외전환사채포함)발행후만기전사채취득
# 01370863 그린리소스          	 ⭕
# 00532059 그린생명과학         	 ⭕
# 00105156 극동유화           	 ⭕
# 00454946 그린케미칼          	 ⭕
# 00602279 그린플러스          	 20211216: 주요사항보고서(유상증자결정)
# 00783246 글로벌에스엠         	 ⭕
# 01042711 글로벌텍스프리        	 20240130: [기재정정]전환청구권행사
# 00159731 글로본            	 20230530: 전환사채(해외전환사채포함)발행후만기전사채취득(제3회차)
# 00105475 금강철강           	 ⭕
# 00105299 금강공업           	 ⭕
# 00872656 금양그린파워         	 20231219: 유상증자결정(종속회사의주요경영사항)
# 00168401 금비             	 ⭕
# 00106119 금양             	 20231228: 단기차입금증가결정
# 00106313 금호건설           	 20220510: [기재정정]주요사항보고서(유상증자결정)
# 00106368 금호석유화학         	 20200820: [기재정정]감자결정(자율공시)(종속회사의주요경영사항)
# 00105606 금호에이치티         	 20240122: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00106395 금호전기           	 20240103: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00176516 금화피에스시         	 ⭕
# 00481454 금호타이어          	 20231212: [기재정정]유상증자결정(종속회사의주요경영사항)
# 00377018 기가레인           	 20221220: [기재정정]전환청구권행사
# 00765569 기가비스           	 ⭕
# 00258421 기산텔레콤          	 20190809: 단기차입금증가결정
# 00106614 기신정기           	 ⭕
# 00149646 기업은행           	 20210416: 주요사항보고서(유상증자결정)
# 00106641 기아             	 ⭕
# 00129420 까뮤이앤씨          	 20231226: 단기차입금증가결정
# 01181807 까스텔바작          	 20230915: 주요사항보고서(전환사채권발행결정)
# 00113492 깨끗한나라          	 20190326: [기재정정]주요사항보고서(감자결정)
# 01586455 꿈비             	 20230622: 증권발행결과(자율공시)(일반공모 유상증자)
# 00994994 나노             	 20230821: 전환청구권행사
# 01136001 나노브릭           	 20240216: [기재정정]주요사항보고서(자기전환사채매도결정)
# 00230425 나노엔텍           	 ⭕
# 01524118 나노팀            	 ⭕
# 01021639 나라셀라           	 ⭕
# 00542074 나노캠텍           	 20240102: [기재정정]주요사항보고서(전환사채권발행결정)
# 00362122 나래나노텍          	 ⭕
# 00297095 나라엠앤디          	 ⭕
# 00819374 나무가            	 20220210: 파생상품거래손실발생
# 01136348 나무기술           	 20210621: 전환청구권행사(제5회차)
# 00486097 나스미디어          	 20200227: [기재정정]유상증자결정(종속회사의주요경영사항)
# 00767628 나이벡            	 20231228: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00606293 나이스디앤비         	 ⭕
# 00264945 나이스정보통신        	 ⭕
# 01208849 나인테크           	 20240119: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00651017 나우IB           	 ⭕
# 00107066 남광토건           	 20230228: 단기차입금증가결정
# 00172185 남성             	 20240201: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00107224 남선알미늄          	 20220826: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00107598 남양유업           	 20230612: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00245694 남화산업           	 ⭕
# 00107987 남해화학           	 20230421: 단기차입금증가결정
# 00108001 남화토건           	 ⭕
# 00923792 내츄럴엔도텍         	 20220413: 전환청구권행사(제10회차)
# 00599106 네오리진           	 20240115: [기재정정]주요사항보고서(유상증자결정)
# 00876865 네오오토           	 20240207: [기재정정]주요사항보고서(전환사채권발행결정)
# 01170865 네오셈            	 20231214: 전환청구권행사
# 00628860 네오위즈           	 ⭕
# 00266952 네오위즈홀딩스        	 ⭕
# 01511558 네오이뮨텍          	 ⭕
# 01219155 네오크레마          	 20230814: 파생상품거래손실발생
# 00447928 네오티스           	 20220104: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00551920 네오팜            	 20190617: [기재정정]주요사항보고서(유상증자결정)
# 01246034 네오펙트           	 20231226: [기재정정]주요사항보고서(유상증자결정)
# ...
# 00162993 한일홀딩스          	 20211125: 횡령ㆍ배임혐의발생
# 00267979 한일화학           	 ⭕
# 00156600 한주라이트메탈        	 20230629: 주요사항보고서(전환사채권발행결정)
# 00159218 한전KPS          	 ⭕
# 00159209 한전기술           	 20201127: 횡령ㆍ배임혐의발생
# 00194947 한전산업           	 20201218: 단기차입금증가결정
# 00163512 한진             	 20230724: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00202839 한창산업           	 ⭕
# 00163673 한진중공업홀딩스       	 20230727: [기재정정]유상증자결정(자회사의 주요경영사항)
# 00983040 한진칼            	 20220216: 영업정지(종속회사의주요경영사항)
# 00163716 한창             	 20231130: [기재정정]주요사항보고서(전환사채권발행결정)
# 00163761 한창제지           	 20190729: 단기차입금증가결정
# 00534598 한컴라이프케어        	 ⭕
# 00363592 한컴위드           	 20210127: 단기차입금증가결정
# 00140566 한탑             	 20240125: 증권발행결과(자율공시)(제3자배정 유상증자)
# 00160588 한화             	 20230727: [기재정정]유상증자결정(종속회사의주요경영사항)
# 01722437 한화갤러리아         	 ⭕
# 00113058 한화생명           	 20231208: 단기차입금증가결정
# 00135917 한화손해보험         	 20231226: 유상증자결정(종속회사의주요경영사항)
# 00162461 한화솔루션          	 20230818: 유상증자결정(종속회사의주요경영사항)
# 00339391 한화시스템          	 20230222: [기재정정]유상증자결정(종속회사의주요경영사항)
# 00126566 한화에어로스페이스      	 20220225: [기재정정]유상증자결정(종속회사의주요경영사항)
# 01572489 한화플러스제2호스팩     	 ⭕
# 00111704 한화오션           	 20231116: 유상증자또는주식관련사채등의발행결과(자율공시)
# 01725160 한화플러스제4호스팩     	 ⭕
# 01663055 한화플러스제3호스팩     	 ⭕
# 00148610 한화투자증권         	 20221114: 단기차입금증가결정
# 00453442 해성티피씨          	 20240208: 주요사항보고서(전환사채권발행결정)
# 01032413 해성디에스          	 ⭕
# 00219361 해성산업           	 20211115: 유상증자또는주식관련사채등의청약결과(자율공시)
# 00483735 해성옵틱스          	 20240208: [기재정정]주요사항보고서(전환사채권발행결정)
# 00428321 해태제과식품         	 ⭕
# 01160512 헝셩그룹           	 20231219: 증권발행결과(자율공시)(제3자배정 유상증자-현물출자)
# 00793155 핸디소프트          	 20200120: 주요사항보고서(영업정지)
# 00119140 핸즈코퍼레이션        	 20240102: [기재정정]유상증자결정(종속회사의주요경영사항)
# 01013311 헥토이노베이션        	 20190702: [기재정정]유상증자결정(종속회사의주요경영사항)
# 00763701 헥토파이낸셜         	 ⭕
# 00359395 헬릭스미스          	 20240205: [기재정정]주요사항보고서(유상증자결정)
# 01721809 현대그린푸드         	 ⭕
# 00164478 현대건설           	 20220128: [기재정정]유상증자결정(종속회사의주요경영사항)
# 00164502 현대공업           	 ⭕
# 00360595 현대글로비스         	 ⭕
# 00302926 현대로템           	 20221219: 단기차입금증가결정
# 00300548 현대리바트          	 20230809: 단기차입금증가결정
# 01358463 현대무벡스          	 20231109: 단기차입금증가결정
# 00164788 현대모비스          	 ⭕
# 00164609 현대미포조선         	 ⭕
# 00313649 현대바이오          	 20220322: 전환청구권행사
# 00347062 현대바이오랜드        	 ⭕
# 00428251 현대백화점          	 20200206: 유상증자결정(종속회사의주요경영사항)
# 00125743 현대비앤지스틸        	 ⭕
# 00255044 현대에이치티         	 ⭕
# 00164706 현대약품           	 20230511: 단기차입금증가결정
# 00228536 현대에버다임         	 ⭕
# 00362441 현대오토에버         	 ⭕
# 00164724 현대엘리베이터        	 20230406: [기재정정]감자결정(종속회사의주요경영사항)
# 00106623 현대위아           	 20240131: 유상증자결정(종속회사의주요경영사항)
# 00656951 현대이지웰          	 20200603: 전환청구권행사
# 00164742 현대자동차          	 ⭕
# 00145880 현대제철           	 20231026: 유상증자결정(종속회사의주요경영사항)
# 00105280 현대지에프홀딩스       	 20231215: [기재정정]주요사항보고서(감자결정)
# 01108099 현대코퍼레이션홀딩스     	 ⭕
# 00164812 현대코퍼레이션        	 ⭕
# 00137997 현대차증권          	 20221104: 단기차입금증가결정
# 00403632 현대퓨처넷          	 20220221: 주요사항보고서(감자결정)
# 00164973 현대해상           	 ⭕
# 00667373 현대힘스           	 ⭕
# 00367455 현우산업           	 20230922: 주요사항보고서(전환사채권발행결정)
# 00412597 현대홈쇼핑          	 20200629: 단기차입금증가결정(자회사의 주요경영사항)
# 00808068 협진             	 20240110: [기재정정]주요사항보고서(전환사채권발행결정)
# 00142713 형지I&C          	 20230808: 주요사항보고서(전환사채권발행결정)
# 00441243 형지엘리트          	 20240207: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00165343 혜인             	 ⭕
# 00226316 호전실업           	 20240122: 기타경영사항(자율공시)(전환사채의 만기 전 조기상환)
# 00385336 홈캐스트           	 20211208: [기재정정]주요사항보고서(유상증자결정)
# 00165680 호텔신라           	 20230712: 단기차입금증가결정
# 00288495 홈센타홀딩스         	 20210302: 유상증자또는주식관련사채등의청약결과(자율공시)
# 00217743 화성밸브           	 ⭕
# 00174527 화성산업           	 20221226: 단기차입금증가결정
# 01532603 화승알앤에이         	 ⭕
# 01128613 화승엔터프라이즈       	 20200317: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00166227 화승인더스트리        	 ⭕
# 00166272 화승코퍼레이션        	 ⭕
# 00166315 화신             	 ⭕
# 00825223 화신정공           	 ⭕
# 00661847 화인베스틸          	 20230707: 유상증자또는주식관련사채등의발행결과(자율공시)
# 00188973 화일약품           	 20240129: 주요사항보고서(영업정지)
# 00166519 화천기공           	 ⭕
# 00166500 화천기계           	 ⭕
# 00527002 화인써키트          	 20230918: [기재정정]전환청구권행사(제1회차)
# 00367385 효성오앤비          	 ⭕
# 00166573 환인제약           	 ⭕
# 00218575 황금에스티          	 20190808: 감자결정(종속회사의주요경영사항)
# 00117188 효성             	 20201230: 횡령ㆍ배임사실확인
# 00414850 효성 ITX         	 20190410: 단기차입금증가결정
# 01316245 효성중공업          	 20200731: 유상증자결정(종속회사의주요경영사항)
# 00595191 후성             	 20240125: 주요사항보고서(유상증자결정)
# 01316227 효성티앤씨          	 20211220: 유상증자결정(종속회사의주요경영사항)
# 00195229 휠라홀딩스          	 20231114: 유상증자결정(자회사의 주요경영사항)
# 00111421 휴니드테크놀러지스      	 ⭕
# 01251577 휴네시온           	 ⭕
# 01316236 효성화학           	 20231226: 유상증자결정(종속회사의주요경영사항)
# 01453670 휴럼             	 20230721: 유상증자결정(종속회사의주요경영사항)
# 00623184 휴림네트웍스         	 20240131: [기재정정]주요사항보고서(유상증자결정)
# 00540429 휴림로봇           	 20240207: [기재정정]주요사항보고서(전환사채권발행결정)
# 00230814 휴림에이텍          	 20231124: 증권발행결과(자율공시)(제3자배정 유상증자-소액공모)
# 01042979 휴마시스           	 20200820: 파생상품거래손실발생
# 00787057 휴맥스            	 20231215: 전환사채(해외전환사채포함)발행후만기전사채취득(제10회차)
# 00219440 휴맥스홀딩스         	 20200902: 주요사항보고서(전환사채권발행결정)(자회사의 주요경영사항)(제12회차)
# 00362238 휴비스            	 ⭕
# 00614478 휴메딕스           	 20230811: 전환청구권행사
# 00398668 휴비츠            	 ⭕
# 01063884 휴센텍            	 20231123: 횡령ㆍ배임혐의진행사항
# 00156488 휴스틸            	 20221213: 유상증자또는주식관련사채등의발행결과(자율공시)
# 01185566 휴엠앤씨           	 20240117: 단기차입금증가결정
# 01159853 휴온스            	 20230814: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00228059 휴온스글로벌         	 20240201: 전환사채(해외전환사채포함)발행후만기전사채취득
# 00167004 흥구석유           	 ⭕
# 00888347 휴젤             	 20230717: 특수관계인에대한전환사채발행의결
# 00167031 흥국             	 ⭕
# 00916516 흥국에프엔비         	 20220429: 주요사항보고서(전환사채권발행결정)
# 00103176 흥국화재           	 ⭕
# 00167208 흥아해운           	 20220711: 단기차입금증가결정
# 00236863 희림             	 20200626: 단기차입금증가결정
# 00556712 힘스             	 ⭕
# 01316254 효성첨단소재         	 20210827: 유상증자결정(종속회사의주요경영사항)

# %%
# @title 4) 최근 3개월 이내 거래량이 발생했는지 여부

from urllib import parse
from ast import literal_eval
from sklearn.ensemble import IsolationForest

with open("screening_03.csv") as file :
    df_disclosure = pd.read_csv(file)

df_disclosure['종목코드'] = df_disclosure['종목코드'].astype(str).str.zfill(6)

# 거래량 기간 설정
# @markdown 거래량 범위 설정 (※최소 3개월 이상으로 설정)
기간 = 1 # @param {type:"integer"}
단위 = '\uB144' # @param ["년", "월", "일"]

end_time = datetime.now().strftime("%Y%m%d")
time_delta = {
    '년': relativedelta(years=기간),
    '월': relativedelta(months=기간),
    '일': relativedelta(days=기간)
}
start_time = (datetime.now() - time_delta[단위]).strftime("%Y%m%d")

def filter_recent_data(df):
    within_3_months_example = df[
        df['날짜'].apply(lambda x: (today - datetime.strptime(str(x), '%Y%m%d')).days <= 90)
    ]
    return within_3_months_example

def calculate_top_volume(volume, df):
    percent = [volume/100]
    df_statistics = df['거래량'].describe(percentiles = percent)
    upper_threshold = df_statistics[f'{volume}%']
    df = df[df['거래량'] > upper_threshold]

    return df

def check_outlier(volume, df):
    df_outlier = calculate_top_volume(volume, df)
    if df_outlier.empty: return "⭕"

    df_within_3_months = filter_recent_data(df_outlier)
    if df_within_3_months.empty: return "⭕"

    return df_within_3_months['날짜'].values[-1]

def lowwer(df):
    target_data = df['저가'].values.reshape(-1, 1)
    return min(target_data)

def upper(df):
    target_data = df['고가'].values.reshape(-1, 1)
    return max(target_data)

async def fetch_page(session, url):
    async with session.get(url) as response:
        return await response.text()

async def process_page(session,code):
    param = {
    	'symbol':code,
	    'requestType':1,
	    'startTime':start_time,
	    'endTime':end_time,
	    'timeframe':'day'
    }
    param_url = parse.urlencode(param)
    url="https://api.finance.naver.com/siseJson.naver?%s"%(param_url)

    response = await fetch_page(session, url)
    response_list = literal_eval(response.strip())
    df_temp = pd.DataFrame(response_list[1:], columns=response_list[0])

    return df_temp

async def fetch_volume(session, df, code):
    try:
        # @markdown 거래량 범위 내 거래량 상위 n%가 3개월 이내 존재여부
        거래량_1 = 95 # @param {type:"slider", min:75, max:100, step:1}
        거래량_2 = 98 # @param {type:"slider", min:75, max:100, step:1}

        df_volume = await process_page(session, code)
        volume_1 = check_outlier(거래량_1, df_volume)
        volume_2 = check_outlier(거래량_2, df_volume)
        lowwer_value = lowwer(df_volume)[0]
        upper_value = upper(df_volume)[0]

        print('{:<7} {:<14} \t{:<6} \t{:<6}'.format(
            code,
            df[df['종목코드'] == code]['종목명'].values[0],
            volume_1, volume_2
        ))

        df.loc[df['종목코드'] == code, f'거래량 상위{거래량_1}%'] = volume_1
        df.loc[df['종목코드'] == code, f'거래량 상위{거래량_2}%'] = volume_2
        df.loc[df['종목코드'] == code, f'52주 최저가'] = lowwer_value
        df.loc[df['종목코드'] == code, f'52주 최고가'] = upper_value

    except Exception as e:
        print(f"Error processing {code}: {e}")
        return

async def main():
    async with aiohttp.ClientSession() as session:
        tasks = [fetch_volume(session, df_disclosure, code) for code in df_disclosure['종목코드']]
        await asyncio.gather(*tasks)

    return df_disclosure

df_volume = await main()
df_volume.to_csv("screening_04.csv", encoding="utf-8-sig", index=False)
# Out:
# 456440  DB금융스팩11호      	⭕      	⭕
# 138930  BNK금융지주        	20240219 	20240219
# 069730  DSR제강          	⭕      	⭕
# 000120  CJ대한통운         	20240202 	20231201
# 035760  CJ ENM         	20240215 	20240215
# 245620  EDGC           	20240131 	20240131
# 241520  DSC인베스트먼트      	20240220 	20240214
# 139130  DGB금융지주        	20240208 	20240202
# 054620  APS            	20240115 	⭕
# 028300  HLB            	20240219 	20240129
# 011200  HMM            	20240112 	20231222
# 097950  CJ제일제당         	⭕      	⭕
# 013720  CBI            	20240105 	20240105
# 900290  GRT            	⭕      	⭕
# 180400  DXVX           	20240119 	20240116
# 017940  E1             	20240102 	20240102
# 060310  3S             	20240122 	20240112
# 099520  ITX-AI         	⭕      	⭕
# 095570  AJ네트웍스         	20231219 	⭕
# 078930  GS             	20240207 	20240202
# 403870  HPSP           	20240214 	20240214
# 115450  HLB테라퓨틱스       	20240220 	20240130
# 440290  HB인베스트먼트       	20240125 	20240125
# 006360  GS건설           	⭕      	⭕
# 025440  DH오토웨어         	20231201 	⭕
# 009540  HD한국조선해양       	⭕      	⭕
# 017860  DS단석           	20231227 	20231226
# 078150  HB테크놀러지        	20240123 	⭕
# 175330  JB금융지주         	20240220 	20240201
# 095340  ISC            	⭕      	⭕
# 375500  DL이앤씨          	20240205 	20240202
# 083790  CG인바이츠         	20240208 	⭕
# 012630  HDC            	20240214 	20240213
# 079160  CJ CGV         	⭕      	⭕
# 051500  CJ프레시웨이        	20240205 	20240205
# 311690  CJ 바이오사이언스     	⭕      	⭕
# 126600  BGF에코머티리얼즈     	20240122 	⭕
# 001040  CJ             	20240201 	⭕
# 383220  F&F            	20240213 	20240213
# 082740  HSD엔진          	20240130 	20240130
# 007700  F&F 홀딩스        	20240207 	20240202
# 114090  GKL            	20240219 	⭕
# 083450  GST            	20240219 	20240215
# 448760  IBKS제22호스팩     	⭕      	⭕
# 139050  BF랩스           	⭕      	⭕
# 001460  BYC            	20240124 	20240124
# 204320  HL만도           	20240208 	20240207
# 267250  HD현대           	20240205 	20240205
# 000590  CS홀딩스          	20240220 	⭕
# 000990  DB하이텍          	20231228 	⭕
# 037370  EG             	⭕      	⭕
# 004840  DRB동일          	20240206 	⭕
# 036640  HRS            	⭕      	⭕
# 211270  AP위성           	20240108 	20240104
# 016610  DB금융투자         	20240219 	20240202
# 011150  CJ씨푸드          	20231228 	⭕
# 001880  DL건설           	20240202 	20240202
# 267270  HD현대건설기계       	20240206 	20240206
# 005830  DB손해보험         	20240202 	20240202
# 012030  DB             	⭕      	⭕
# 329180  HD현대중공업        	20231206 	⭕
# 068790  DMS            	20240109 	20231226
# 047920  HLB제약          	20240206 	20240205
# 155660  DSR            	⭕      	⭕
# 265520  AP시스템          	20231221 	20231219
# 065770  CS             	20240126 	20240126
# 089470  HDC현대EP        	⭕      	⭕
# 027410  BGF            	20240213 	20240202
# 024850  HLB이노베이션       	20240207 	⭕
# 014790  HL D&I         	20240201 	⭕
# 195940  HK이노엔          	20240103 	20240103
# 035000  HS애드           	⭕      	⭕
# 214270  FSN            	20240206 	20240206
# 297890  HB솔루션          	20240130 	20240129
# 439730  IBKS제20호스팩     	20231129 	20231129
# 007070  GS리테일          	⭕      	⭕
# 950170  JTC            	⭕      	⭕
# 282330  BGF리테일         	20240205 	20231227
# 234080  JW생명과학         	⭕      	⭕
# 001250  GS글로벌          	⭕      	⭕
# 130500  GH신소재          	20231207 	20231207
# 060900  DGP            	20240115 	20240115
# 001060  JW중외제약         	⭕      	⭕
# 096760  JW홀딩스          	20231207 	20231207
# 035900  JYP Ent.       	20240129 	20240116
# 024840  KBI메탈          	⭕      	⭕
# 105560  KB금융           	20240215 	20240215
# 322000  HD현대에너지솔루션     	20231220 	20231220
# 024120  KB오토시스         	⭕      	⭕
# 050120  ES큐브           	20240220 	20240220
# 067290  JW신약           	20231207 	⭕
# 007340  DN오토모티브        	20240105 	20240105
# 318000  KBG            	⭕      	⭕
# 003580  HLB글로벌         	20240220 	20240220
# 278650  HLB바이오스텝       	20240205 	20240205
# 097230  HJ중공업          	20240102 	20231228
# 058820  CMG제약          	20231226 	20231207
# 455250  KB제25호스팩       	20240219 	⭕
# 056730  CNT85          	20231218 	20231218
# 046210  HLB파나진         	20240206 	20240129
# 083660  CSA 코스믹        	20231221 	⭕
# 458320  KB제26호스팩       	⭕      	⭕
# 015590  KIB플러그에너지      	20240213 	20240206
# 044450  KSS해운          	20240119 	20240117
# 009440  KC그린홀딩스        	20231122 	20231122
# 151860  KG ETS         	⭕      	⭕
# 008260  NI스틸           	20240130 	⭕
# 058860  KTis           	20231129 	20231129
# 383800  LX홀딩스          	20240205 	20240202
# 036670  KCI            	20240207 	⭕
# 058850  KTcs           	20240123 	20240119
# 001390  KG케미칼          	20231205 	⭕
# 119650  KC코트렐          	20240110 	⭕
# 035420  NAVER          	20240205 	⭕
# 023150  MH에탄올          	⭕      	⭕
# 053290  NE능률           	⭕      	⭕
# 086960  MDS테크          	⭕      	⭕
# 051910  LG화학           	20240208 	20240208
# 060250  NHN KCP        	20240220 	20240220
# 108320  LX세미콘          	⭕      	⭕
# 052900  KX하이텍          	20240130 	20240126
# 021320  KCC건설          	20240105 	20231221
# 011070  LG이노텍          	20240126 	20231215
# 003550  LG             	20240219 	20240201
# 417200  LS머트리얼즈        	20231219 	20231214
# 079550  LIG넥스원         	20240214 	20231222
# 046440  KG모빌리언스        	⭕      	⭕
# 038340  MIT            	⭕      	⭕
# 037560  LG헬로비전         	20240124 	20240119
# 060370  LS마린솔루션        	20231213 	⭕
# 229640  LS에코에너지        	20231221 	⭕
# 066570  LG전자           	20231207 	20231207
# 309960  LB인베스트먼트       	20240115 	20240115
# 000680  LS네트웍스         	20240124 	20240124
# 093050  LF             	20240219 	20231130
# 061970  LB세미콘          	20240201 	20240130
# 001120  LX인터내셔널        	20231227 	⭕
# 373220  LG에너지솔루션       	⭕      	⭕
# 060720  KH바텍           	⭕      	⭕
# 010060  OCI홀딩스         	20240115 	⭕
# 006260  LS             	⭕      	⭕
# 000040  KR모터스          	20240207 	⭕
# 092230  KPX홀딩스         	20240208 	⭕
# 218410  RFHIC          	20240117 	⭕
# 032640  LG유플러스         	20240131 	20240131
# 058400  KNN            	20231227 	20231227
# 005490  POSCO홀딩스       	⭕      	⭕
# 003620  KG모빌리티         	⭕      	⭕
# 001940  KISCO홀딩스       	20240207 	⭕
# 327260  RF머트리얼즈        	20240201 	⭕
# 034220  LG디스플레이        	20240108 	20240108
# 376190  LB루셈           	20240207 	20240129
# 092220  KEC            	20240116 	20240116
# 104200  NHN벅스          	20240220 	20240119
# 122450  KX             	20231222 	20231222
# 025000  KPX케미칼         	20240220 	20240219
# 111870  KH 전자          	⭕      	⭕
# 178920  PI첨단소재         	⭕      	⭕
# 226360  KH 건설          	⭕      	⭕
# 044180  KD             	⭕      	⭕
# 035600  KG이니시스         	20240220 	20231207
# 051900  LG생활건강         	20240216 	20240215
# 033180  KH 필룩스         	⭕      	⭕
# 160550  NEW            	20231219 	20231219
# 456040  OCI            	⭕      	⭕
# 030190  NICE평가정보       	20240215 	⭕
# 024940  PN풍년           	⭕      	⭕
# 034310  NICE           	20240201 	20240125
# 222160  NPX            	20231228 	⭕
# 442770  IBKS제21호스팩     	⭕      	⭕
# 039570  HDC랩스          	20240220 	⭕
# 023460  CNH            	20231228 	⭕
# 091340  S&K폴리텍         	20231204 	20231204
# 000210  DL             	20240208 	20240208
# 060980  HL홀딩스          	20240213 	20240205
# 067630  HLB생명과학        	20240219 	20240202
# 006840  AK홀딩스          	20240201 	⭕
# 267260  HD현대일렉트릭       	20240103 	⭕
# 419530  SAMG엔터         	20231222 	20231222
# 099220  SDN            	20240116 	20240116
# 010950  S-Oil          	⭕      	⭕
# 036540  SFA반도체         	20240126 	20240124
# 040610  SG&G           	20240207 	20240207
# 950110  SBI핀테크솔루션즈     	20231213 	20231212
# 036120  SCI평가정보        	20240111 	⭕
# 034120  SBS            	20240110 	20240109
# 019550  SBI인베스트먼트      	20240215 	20240111
# 001770  SHD            	20240112 	20240112
# 016250  SGC이테크건설       	20231226 	20231222
# 108670  LX하우시스         	20231212 	20231212
# 004060  SG세계물산         	20240219 	20231201
# 005090  SGC에너지         	20231227 	⭕
# 001380  SG글로벌          	20231201 	20231130
# 049470  SGA            	20231221 	⭕
# 184230  SGA솔루션즈        	20231221 	20231221
# 005940  NH투자증권         	20240202 	20240202
# 016380  KG스틸           	⭕      	⭕
# 255220  SG             	20231219 	⭕
# 042670  HD현대인프라코어      	20240205 	⭕
# 151910  SBW생명과학        	20240219 	20240216
# 009160  SIMPAC         	20240201 	20231215
# 002360  SH에너지화학        	20240118 	20240117
# 034730  SK             	20240219 	20240202
# 011790  SKC            	⭕      	⭕
# 294870  HDC현대산업개발      	20240129 	20240126
# 001740  SK네트웍스         	20240219 	20240214
# 302440  SK바이오사이언스      	⭕      	⭕
# 402340  SK스퀘어          	20240219 	20240207
# 096770  SK이노베이션        	⭕      	⭕
# 100090  SK오션플랜트        	20231214 	⭕
# 032540  TJ미디어          	20240214 	20231211
# 435870  SK증권제8호스팩      	⭕      	⭕
# 006120  SK디스커버리        	20240219 	20240219
# 048770  TPC            	20240125 	20240124
# 018670  SK가스           	20231215 	⭕
# 077970  STX엔진          	⭕      	⭕
# 051390  YW             	⭕      	⭕
# 002710  TCC스틸          	⭕      	⭕
# 035250  강원랜드           	20240219 	20240219
# 246690  TS인베스트먼트       	20240215 	20240215
# 361610  SK아이이테크놀로지     	⭕      	⭕
# 012610  경인양행           	⭕      	⭕
# 000050  경방             	⭕      	⭕
# 399720  가온칩스           	20240214 	20231222
# 214390  경보제약           	20231123 	⭕
# 009140  경인전자           	20240123 	20240116
# 000860  강남제비스코         	⭕      	⭕
# 036620  감성코퍼레이션        	20240214 	20240214
# 063440  SM Life Design 	20240129 	20240110
# 198440  고려시멘트          	⭕      	⭕
# 040300  YTN            	⭕      	⭕
# 052220  iMBC           	⭕      	⭕
# 079940  가비아            	20240122 	20231228
# 005610  SPC삼립          	20231130 	20231130
# 002900  TYM            	20240112 	20231221
# 267290  경동도시가스         	20240104 	⭕
# 217730  강스템바이오텍        	20231222 	20231215
# 000500  가온전선           	20240216 	20240126
# 011040  경동제약           	20231207 	20231205
# 121440  골프존뉴딘홀딩스       	20240220 	20240213
# 071970  STX중공업         	⭕      	⭕
# 215000  골프존            	20231219 	20231219
# 001510  SK증권           	20240201 	20231214
# 011420  갤럭시아에스엠        	20240215 	20240215
# 014570  고려제약           	20240213 	⭕
# 285130  SK케미칼          	20240103 	20240103
# 039240  경남스틸           	⭕      	⭕
# 009450  경동나비엔          	20240129 	⭕
# 036530  SNT홀딩스         	20240216 	20240216
# 022220  TKG애강          	⭕      	⭕
# 053950  경남제약           	20231208 	20231206
# 317240  TS트릴리온         	20240208 	20240208
# 094480  갤럭시아머니트리       	20240215 	20231205
# 057030  YBM넷           	20231214 	20231213
# 002100  경농             	⭕      	⭕
# 089230  THE E&M        	20231206 	⭕
# 900280  골든센츄리          	20240214 	20240202
# 048550  SM C&C         	20240129 	⭕
# 289080  SV인베스트먼트       	20240123 	20231220
# 003570  SNT다이내믹스       	20231201 	⭕
# 455910  SK증권제9호스팩      	⭕      	⭕
# 465770  STX그린로지스       	20231204 	⭕
# 000660  SK하이닉스         	20240213 	⭕
# 161570  THE MIDONG     	20231211 	20231204
# 010130  고려아연           	20231208 	⭕
# 012200  계양전기           	20231222 	⭕
# 100840  SNT에너지         	20240201 	20240201
# 024070  WISCOM         	20240130 	⭕
# 037270  YG PLUS        	20231207 	20231206
# 017670  SK텔레콤          	20231214 	20231130
# 012320  경동인베스트         	⭕      	⭕
# 049720  고려신용정보         	⭕      	⭕
# 950190  고스트스튜디오        	20240213 	20240125
# 035290  골드앤에스          	⭕      	⭕
# 098460  고영             	20240219 	20240125
# 024910  경창산업           	⭕      	⭕
# 002240  고려제강           	20240220 	20240214
# 114190  강원에너지          	⭕      	⭕
# 013580  계룡건설산업         	20240201 	⭕
# 078890  가온그룹           	20240220 	20240219
# 002820  SUN&L          	20240125 	20240124
# 457940  SK증권제10호스팩     	⭕      	⭕
# 348150  고바이오랩          	20240116 	20240105
# 064960  SNT모티브         	20240202 	⭕
# 366030  공구우먼           	20240202 	20240131
# 014200  광림             	⭕      	⭕
# 456490  교보14호스팩        	⭕      	⭕
# 421800  교보12호스팩        	20240206 	20240206
# 440790  교보13호스팩        	20240112 	⭕
# 009290  광동제약           	20240119 	20231205
# 026910  광진실업           	⭕      	⭕
# 017040  광명전기           	20231127 	20231124
# 397880  교보11호스팩        	20240220 	20240201
# 037710  광주신세계          	20240207 	20240129
# 017900  광전자            	20240118 	20240116
# 210980  SK디앤디          	20231228 	⭕
# 002140  고려산업           	20240118 	⭕
# 339770  교촌에프앤비         	20240220 	20240104
# 011810  STX            	20231130 	20231130
# 030610  교보증권           	20240220 	20240201
# 029480  광무             	⭕      	⭕
# 002720  국제약품           	20231207 	20231204
# 043650  국순당            	20240214 	20240123
# 204020  그리티            	⭕      	⭕
# 035080  그래디언트          	20240111 	20231214
# 308100  까스텔바작          	⭕      	⭕
# 004270  남성             	⭕      	⭕
# 066620  국보디자인          	20240130 	⭕
# 253590  네오셈            	20240215 	20240215
# 121600  나노신소재          	⭕      	⭕
# 083420  그린케미칼          	20240117 	20240116
# 089600  나스미디어          	20240124 	20240124
# 036800  나이스정보통신        	20240205 	⭕
# 187790  나노             	20231124 	⭕
# 267320  나인테크           	⭕      	⭕
# 008350  남선알미늄          	20240102 	20231211
# 011780  금호석유화학         	20240219 	20240219
# 417010  나노팀            	⭕      	⭕
# 247660  나노씨엠에스         	⭕      	⭕
# 311390  네오크레마          	⭕      	⭕
# 000270  기아             	20240213 	20240207
# 204620  글로벌텍스프리        	20231213 	⭕
# 420770  기가비스           	20231127 	⭕
# 036190  금화피에스시         	20240205 	⭕
# 092730  네오팜            	20240110 	⭕
# 085910  네오티스           	20240122 	20240109
# 024110  기업은행           	20240219 	20240206
# 290660  네오펙트           	20240131 	20240131
# 033640  네패스            	20240103 	20240102
# 001140  국보             	20240202 	20240202
# 111710  남화산업           	20240109 	20231208
# 004540  깨끗한나라          	20240123 	20240119
# 053260  금강철강           	20240202 	20240130
# 001210  금호전기           	⭕      	⭕
# 138610  나이벡            	20240104 	20231212
# 006050  국영지앤엠          	20231208 	⭕
# 130580  나이스디앤비         	20240112 	⭕
# 001260  남광토건           	⭕      	⭕
# 168330  내츄럴엔도텍         	20240119 	20240111
# 190510  나무가            	20240215 	20240131
# 900070  글로벌에스엠         	⭕      	⭕
# 282720  금양그린파워         	⭕      	⭕
# 114450  그린생명과학         	20231211 	20231208
# 051490  나라엠앤디          	20240215 	20240215
# 001570  금양             	⭕      	⭕
# 137080  나래나노텍          	20231212 	⭕
# 095660  네오위즈           	20240202 	20240202
# 039860  나노엔텍           	20240220 	20240220
# 007690  국도화학           	20231220 	⭕
# 307750  국전약품           	20231208 	20231207
# 092440  기신정기           	20240125 	⭕
# 242040  나무기술           	20240119 	20231227
# 407400  꿈비             	20240103 	⭕
# 091590  남화토건           	20231211 	20231208
# 060480  국일신동           	⭕      	⭕
# 025860  남해화학           	20231208 	20231208
# 402490  그린리소스          	20231128 	20231127
# 405920  나라셀라           	20240130 	⭕
# 073240  금호타이어          	20240130 	20240125
# 002990  금호건설           	20240219 	20231226
# 008870  금비             	⭕      	⭕
# 293580  나우IB           	⭕      	⭕
# 094860  네오리진           	20240219 	20240213
# 078130  국일제지           	⭕      	⭕
# 212560  네오오토           	20231221 	20231221
# 019660  글로본            	20240215 	20240213
# 049080  기가레인           	20240115 	20240110
# 014280  금강공업           	⭕      	⭕
# 013700  까뮤이앤씨          	20231212 	20231212
# 186230  그린플러스          	20231219 	⭕
# 035460  기산텔레콤          	⭕      	⭕
# 950220  네오이뮨텍          	20240119 	⭕
# 214330  금호에이치티         	20231122 	⭕
# 014530  극동유화           	20240104 	⭕
# 003920  남양유업           	20240219 	20240105
# 286750  나노브릭           	⭕      	⭕
# 153460  네이블커뮤니케이션즈     	20240112 	20240112
# 042420  네오위즈홀딩스        	20240111 	20231207
# 330860  네패스아크          	20240219 	20240219
# 053270  구영테크           	⭕      	⭕
# 002350  넥센타이어          	20240205 	⭕
# 285490  노바텍            	⭕      	⭕
# 106520  노블엠앤비          	⭕      	⭕
# 348210  넥스틴            	20240125 	⭕
# 000320  노루홀딩스          	20240215 	20240214
# 376930  노을             	20231221 	20231215
# 194700  노바렉스           	20231211 	20231211
# 092790  넥스틸            	⭕      	⭕
# 396270  넥스트칩           	20231219 	⭕
# 090350  노루페인트          	20240220 	20240214
# 137940  넥스트아이          	20240102 	20231213
# 104620  노랑풍선           	20240129 	20240126
# 217270  넵튠             	⭕      	⭕
# 005720  넥센             	20240205 	20240205
# 089140  넥스턴바이오         	⭕      	⭕
# 251270  넷마블            	20231214 	⭕
# 225570  넥슨게임즈          	20240202 	20240202
# 091970  나노캠텍           	20240119 	⭕
# 306620  네온테크           	20240111 	20240110
# 005320  국동             	20231227 	20231227
# 007390  네이처셀           	⭕      	⭕
# 060260  뉴보텍            	⭕      	⭕
# 065560  녹원씨엔아이         	⭕      	⭕
# 004370  농심             	20240208 	⭕
# 129920  대성하이텍          	⭕      	⭕
# 006280  녹십자            	20231219 	20231218
# 104040  대성파인텍          	⭕      	⭕
# 117580  대성에너지          	20240122 	20240117
# 019680  대교             	20240208 	20240104
# 008830  대동기어           	20240126 	20231226
# 128820  대성산업           	20240104 	20231129
# 457630  대신밸런스제16호스팩    	⭕      	⭕
# 108380  대양전기공업         	⭕      	⭕
# 084690  대상홀딩스          	20231213 	20231207
# 014160  대영포장           	20240220 	20240220
# 009190  대양금속           	20240129 	20240118
# 145210  다이나믹디자인        	⭕      	⭕
# 006580  대양제지           	20240117 	20240116
# 000430  대원강업           	⭕      	⭕
# 048910  대원미디어          	20240124 	20240124
# 000490  대동             	20231226 	20231222
# 003090  대웅             	20240202 	20240201
# 030210  다올투자증권         	⭕      	⭕
# 005750  대림비앤코          	20240220 	⭕
# 389260  대명에너지          	⭕      	⭕
# 003540  대신증권           	20240202 	20240201
# 032190  다우데이타          	20240201 	20240130
# 006570  대림통상           	⭕      	⭕
# 016710  대성홀딩스          	⭕      	⭕
# 290670  대보마그네틱         	20231215 	⭕
# 001680  대상             	20231213 	20231213
# 353200  대덕전자           	20231213 	20231213
# 007720  대명소노시즌         	20240111 	20240111
# 047040  대우건설           	⭕      	⭕
# 020180  대신정보통신         	20240129 	⭕
# 457390  대신밸런스제15호스팩    	⭕      	⭕
# 020400  대동금속           	20240125 	20231228
# 438220  대신밸런스제13호스팩    	⭕      	⭕
# 017650  대림제지           	20240119 	⭕
# 008060  대덕             	20240202 	20240202
# 027830  대성창투           	20240115 	20240112
# 154040  다산솔루에타         	⭕      	⭕
# 078140  대봉엘에스          	20240103 	20231127
# 144960  뉴파워프라즈마        	20240102 	20240102
# 045390  대아티아이          	20231214 	20231123
# 007680  대원             	⭕      	⭕
# 069620  대웅제약           	20240206 	⭕
# 006370  대구백화점          	20240125 	20231228
# 008110  대동전자           	20231222 	20231221
# 348340  뉴로메카           	20240115 	20240112
# 332290  누보             	20240118 	⭕
# 009320  대우부품           	⭕      	⭕
# 442310  대신밸런스제14호스팩    	20240123 	20240118
# 036480  대성미생물          	⭕      	⭕
# 069140  누리플랜           	20240131 	20240131
# 214870  뉴지랩파마          	⭕      	⭕
# 012340  뉴인텍            	⭕      	⭕
# 023590  다우기술           	20240219 	20240213
# 040160  누리플렉스          	20240102 	20231228
# 058730  다스코            	⭕      	⭕
# 072710  농심홀딩스          	20240220 	20240202
# 064260  다날             	20240215 	20240111
# 004780  대륙제관           	20240118 	⭕
# 234690  녹십자웰빙          	20240220 	20240119
# 039560  다산네트웍스         	20240213 	20240111
# 005250  녹십자홀딩스         	20240205 	20231205
# 085670  뉴프렉스           	20240215 	20240202
# 005710  대원산업           	20240202 	20240202
# 142280  녹십자엠에스         	20231218 	20231206
# 270870  뉴트리            	20240123 	20240122
# 065150  대산F&B          	⭕      	⭕
# 317850  대모             	20240213 	20240213
# 006340  대원전선           	20240129 	⭕
# 048470  대동스틸           	20240130 	20240130
# 024890  대원화성           	20231215 	⭕
# 003220  대원제약           	20231221 	20231122
# 290380  대유             	⭕      	⭕
# 054050  농우바이오          	⭕      	⭕
# 340360  다보링크           	20240131 	20240131
# 068240  다원시스           	20240208 	⭕
# 140520  대창스틸           	⭕      	⭕
# 003830  대한화섬           	20240213 	20240202
# 084010  대한제강           	20240201 	20240201
# 005880  대한해운           	20240124 	20240119
# 001790  대한제당           	20231211 	⭕
# 001130  대한제분           	20240201 	20240130
# 001440  대한전선           	20240124 	20240124
# 003490  대한항공           	⭕      	⭕
# 003310  대주산업           	20240118 	⭕
# 010170  대한광통신          	⭕      	⭕
# 002880  대유에이텍          	20231221 	20231221
# 054670  대한뉴팜           	20231205 	⭕
# 078600  대주전자재료         	⭕      	⭕
# 015230  대창단조           	⭕      	⭕
# 131220  대한과학           	20240103 	⭕
# 012800  대창             	20240215 	⭕
# 001070  대한방직           	⭕      	⭕
# 023910  대한약품           	20240219 	20231205
# 006650  대한유화           	⭕      	⭕
# 120240  대정화금           	20240102 	⭕
# 000300  대유플러스          	20240216 	20240216
# 067990  도이치모터스         	20240123 	20231222
# 213420  덕산네오룩스         	20240201 	⭕
# 023450  동남합성           	20240219 	20240219
# 099410  동방선기           	20231128 	⭕
# 194480  데브시스터즈         	20240102 	20231228
# 000640  동아쏘시오홀딩스       	20240207 	20231207
# 004830  덕성             	20240216 	20240216
# 086450  동국제약           	20240215 	20240215
# 090410  덕신하우징          	⭕      	⭕
# 025950  동신건설           	20240104 	20240103
# 001230  동국홀딩스          	20240202 	20240202
# 192080  더블유게임즈         	20240216 	20240216
# 006620  동구바이오제약        	20240129 	20240124
# 012510  더존비즈온          	20240220 	20240206
# 111380  동인기연           	20231123 	20231122
# 082640  동양생명           	20240219 	20240213
# 033500  동성화인텍          	⭕      	⭕
# 007590  동방아그로          	20240219 	20240205
# 088910  동우팜투테이블        	⭕      	⭕
# 002210  동성제약           	20240115 	⭕
# 261200  덴티스            	⭕      	⭕
# 094170  동운아나텍          	20240126 	⭕
# 170900  동아에스티          	20240219 	⭕
# 006040  동원산업           	20240207 	20240117
# 145720  덴티움            	20240102 	20240102
# 282690  동아타이어          	20240220 	20240220
# 028100  동아지질           	20240206 	20240202
# 004140  동방             	20240124 	20240124
# 079960  동양이엔피          	⭕      	⭕
# 163560  동일고무벨트         	20240206 	20240206
# 018500  동원금속           	⭕      	⭕
# 263800  데이타솔루션         	20240201 	20240130
# 002150  도화엔지니어링        	⭕      	⭕
# 298540  더네이쳐홀딩스        	20240119 	20240119
# 014820  동원시스템즈         	⭕      	⭕
# 024900  덕양산업           	20231214 	⭕
# 041930  동아화성           	⭕      	⭕
# 299170  더블유에스아이        	20240103 	20240102
# 317330  덕산테코피아         	20240220 	20240220
# 026960  동서             	⭕      	⭕
# 021040  대호특수강          	20231214 	20231213
# 004890  동일산업           	⭕      	⭕
# 460860  동국제강           	⭕      	⭕
# 001520  동양             	20240205 	20231122
# 102260  동성케미컬          	20240206 	⭕
# 002690  동일제강           	⭕      	⭕
# 005290  동진쎄미켐          	20240112 	⭕
# 030720  동원수산           	20240116 	20240116
# 060380  동양에스텍          	⭕      	⭕
# 088130  동아엘텍           	20240125 	20240124
# 067080  대화제약           	⭕      	⭕
# 092780  동양피스톤          	20231221 	20231221
# 224060  더코디            	20231214 	20231211
# 032860  더라미            	⭕      	⭕
# 084670  동양고속           	20240205 	20240201
# 069460  대호에이엘          	20231123 	⭕
# 008970  동양철관           	20231228 	20231228
# 016090  대현             	20231227 	20231226
# 206560  덱스터            	20240111 	20240109
# 077360  덕산하이메탈         	20240126 	⭕
# 263600  덕우전자           	20240129 	20240108
# 013120  동원개발           	20231226 	20231226
# 005960  동부건설           	20231201 	20231201
# 005160  동국산업           	20240117 	20240116
# 075970  동국알앤에스         	20231218 	⭕
# 393890  더블유씨피          	20240207 	20240207
# 023790  동일철강           	20240214 	20240214
# 460850  동국씨엠           	20240201 	⭕
# 100130  동국S&C          	20240117 	20240116
# 032960  동일기연           	⭕      	⭕
# 109860  동일금속           	⭕      	⭕
# 000020  동화약품           	20240102 	20231207
# 000150  두산             	⭕      	⭕
# 025900  동화기업           	20240220 	20240207
# 049770  동원F&B          	20240215 	⭕
# 228340  동양파일           	⭕      	⭕
# 362990  드림인사이트         	20240126 	20240126
# 223250  드림씨아이에스        	20231226 	20231226
# 217620  디딤이앤에프         	20240220 	20240220
# 001530  디아이동일          	⭕      	⭕
# 024090  디씨엠            	⭕      	⭕
# 454910  두산로보틱스         	20231129 	20231127
# 003160  디아이            	20240220 	20240220
# 016670  디모아            	20240207 	20240118
# 066670  디스플레이텍         	20231219 	20231219
# 187870  디바이스이엔지        	20240125 	20240125
# 336260  두산퓨얼셀          	20240103 	20240103
# 131970  두산테스나          	20240126 	⭕
# 192650  드림텍            	20240123 	20240123
# 092200  디아이씨           	⭕      	⭕
# 110990  디아이티           	20240208 	20240104
# 214680  디알텍            	⭕      	⭕
# 241560  두산밥캣           	20231214 	⭕
# 073190  듀오백            	20240213 	⭕
# 263690  디알젬            	⭕      	⭕
# 016740  두올             	20240205 	⭕
# 030350  드래곤플라이         	20240108 	20231127
# 034020  두산에너빌리티        	⭕      	⭕
# 203650  드림시큐리티         	20240108 	⭕
# 060570  드림어스컴퍼니        	20240126 	20240119
# 196490  디에이테크놀로지       	20240103 	⭕
# 042510  라온시큐어          	20240201 	20240126
# 171120  라이온켐텍          	20231218 	⭕
# 317120  라닉스            	⭕      	⭕
# 004000  롯데정밀화학         	20240110 	20240110
# 171010  램테크놀러지         	20231222 	20231222
# 038390  레드캡투어          	⭕      	⭕
# 281740  레이크머티리얼즈       	⭕      	⭕
# 315640  딥노이드           	⭕      	⭕
# 294140  레몬             	20231201 	⭕
# 215100  로보로보           	20240118 	⭕
# 300120  라온피플           	20240125 	20240123
# 900260  로스웰            	20231228 	⭕
# 131180  딜리             	⭕      	⭕
# 011170  롯데케미칼          	20240202 	20240202
# 092070  디엔에프           	⭕      	⭕
# 290550  디케이티           	20240115 	20240112
# 347700  라이프시맨틱스        	20240219 	20240219
# 210540  디와이파워          	⭕      	⭕
# 127120  디엔에이링크         	20240129 	⭕
# 115390  락앤락            	20240219 	20240219
# 418420  라온텍            	⭕      	⭕
# 197140  디지캡            	20231221 	20231221
# 383930  디티앤씨알오         	20240123 	20240110
# 033130  디지틀조선          	20240102 	20231226
# 104460  디와이피엔에프        	20231213 	⭕
# 113810  디젠스            	⭕      	⭕
# 228850  레이언스           	20240219 	20240219
# 232680  라온테크           	20240207 	20240206
# 069540  라이트론           	20240115 	⭕
# 412350  레이저쎌           	20240130 	⭕
# 277810  레인보우로보틱스       	20231128 	⭕
# 032350  롯데관광개발         	⭕      	⭕
# 310870  디와이씨           	⭕      	⭕
# 290120  디에이치오토리드       	20231221 	20231204
# 067730  로지시스           	20231214 	⭕
# 228670  레이             	⭕      	⭕
# 071280  로체시스템즈         	20240201 	20240129
# 280360  롯데웰푸드          	20240110 	20231206
# 013570  디와이            	⭕      	⭕
# 108490  로보티즈           	20240116 	20240112
# 084650  랩지노믹스          	⭕      	⭕
# 066900  디에이피           	20240124 	20231213
# 023530  롯데쇼핑           	20240213 	20240213
# 004990  롯데지주           	20240219 	20240207
# 217500  러셀             	20240125 	⭕
# 109740  디에스케이          	⭕      	⭕
# 079810  디이엔티           	⭕      	⭕
# 376300  디어유            	⭕      	⭕
# 263720  디앤씨미디어         	20240220 	20240124
# 005300  롯데칠성음료         	20240207 	20240206
# 039980  리노스            	20240220 	20240219
# 443250  레뷰코퍼레이션        	20240117 	20231222
# 105740  디케이락           	⭕      	⭕
# 263020  디케이앤디          	20231228 	20231228
# 090360  로보스타           	20240112 	20240112
# 199550  레이저옵텍          	20240206 	20240206
# 388790  라이콤            	⭕      	⭕
# 068930  디지털대성          	20240220 	20240219
# 058470  리노공업           	20240213 	20240213
# 328130  루닛             	20240216 	⭕
# 219550  디와이디           	20240214 	⭕
# 187220  디티앤씨           	20240109 	20240102
# 000400  롯데손해보험         	20240216 	20240214
# 038060  루멘스            	⭕      	⭕
# 200350  래몽래인           	20240124 	20231212
# 020150  롯데에너지머티리얼즈     	20231130 	20231130
# 060240  룽투코리아          	20240202 	⭕
# 039840  디오             	⭕      	⭕
# 141080  레고켐바이오         	20240123 	20240116
# 286940  롯데정보통신         	20240208 	20240131
# 214260  라파스            	⭕      	⭕
# 089860  롯데렌탈           	20231215 	20231215
# 043360  디지아이           	20240126 	20240126
# 277070  린드먼아시아         	20240220 	20240119
# 067280  멀티캠퍼스          	20240126 	20240102
# 439090  마녀공장           	20231220 	⭕
# 001080  만호제강           	⭕      	⭕
# 093520  매커스            	20240215 	20240213
# 377030  맥스트            	20240116 	20240110
# 005990  매일홀딩스          	20240201 	⭕
# 072870  메가스터디          	20240206 	20240206
# 424980  마이크로투나노        	⭕      	⭕
# 215200  메가스터디교육        	20240208 	20240208
# 027740  마니커            	⭕      	⭕
# 038290  마크로젠           	20240110 	20240109
# 098120  마이크로컨텍솔        	20231222 	⭕
# 267980  매일유업           	20240216 	20240205
# 195500  마니커에프앤지        	⭕      	⭕
# 305090  마이크로디지탈        	⭕      	⭕
# 377480  마음AI           	⭕      	⭕
# 302550  리메드            	20231226 	20231226
# 219420  링크제니시스         	20240215 	20240214
# 042500  링네트            	20240216 	20240119
# 073570  리튬포어스          	20231218 	20231215
# 016100  리더스코스메틱        	⭕      	⭕
# 019570  리더스 기술투자       	20240110 	20240110
# 377450  리파인            	20240129 	⭕
# 012700  리드코프           	20240206 	20240206
# 100590  머큐리            	⭕      	⭕
# 133750  메가엠디           	20240220 	20240206
# 041920  메디아나           	20231124 	⭕
# 446540  메가터치           	20231130 	20231130
# 408920  메쎄이상           	20231129 	20231128
# 086900  메디톡스           	⭕      	⭕
# 065650  메디프론           	20240216 	20240215
# 054180  메디콕스           	20240126 	20231213
# 005360  모나미            	20231215 	⭕
# 001810  무림SP           	⭕      	⭕
# 021880  메이슨캐피탈         	20240102 	20231227
# 446190  미래에셋비전스팩2호     	⭕      	⭕
# 012690  모나리자           	20240205 	20240118
# 033920  무학             	20240205 	20240201
# 363260  모비데이즈          	20240202 	20231222
# 033200  모아텍            	20240110 	⭕
# 009680  모토닉            	20240220 	20240220
# 138040  메리츠금융지주        	⭕      	⭕
# 434480  모니터랩           	⭕      	⭕
# 118990  모트렉스           	⭕      	⭕
# 101330  모베이스           	20240207 	20240205
# 009580  무림P&P          	20240201 	20240201
# 348030  모비릭스           	20240206 	20240206
# 140410  메지온            	⭕      	⭕
# 418470  밀리의서재          	20240118 	⭕
# 059090  미코             	⭕      	⭕
# 268280  미원에스씨          	20240205 	⭕
# 241770  메카로            	20240117 	20240117
# 008420  문배철강           	20240202 	20240130
# 080420  모다이노칩          	⭕      	⭕
# 014100  메디앙스           	20240103 	⭕
# 018700  바른손            	20240104 	20240103
# 279600  미디어젠           	20240126 	20240111
# 134380  미원화학           	⭕      	⭕
# 214610  미코바이오메드        	⭕      	⭕
# 206640  바디텍메드          	20231220 	⭕
# 059210  메타바이오메드        	⭕      	⭕
# 006920  모헨즈            	⭕      	⭕
# 235980  메드팩토           	20240201 	20240129
# 301300  바이브컴퍼니         	20240126 	20240109
# 025560  미래산업           	⭕      	⭕
# 017180  명문제약           	20240102 	20231207
# 377740  바이오노트          	⭕      	⭕
# 288980  모아데이타          	⭕      	⭕
# 053030  바이넥스           	20240215 	20240206
# 201490  미투온            	20240131 	20240131
# 012860  모베이스전자         	20240205 	⭕
# 058110  멕아이씨에스         	20240219 	20231204
# 448830  미래에셋비전스팩3호     	20240129 	20240129
# 078160  메디포스트          	20231129 	20231129
# 087260  모바일어플라이언스      	⭕      	⭕
# 107590  미원홀딩스          	20231204 	20231130
# 095500  미래나노텍          	20240220 	20240220
# 254490  미래반도체          	20231212 	⭕
# 035620  바른손이앤에이        	20240105 	20240104
# 090370  메타랩스           	20231204 	⭕
# 207760  미스터블루          	20240220 	20240220
# 412930  미래에셋비전스팩1호     	20231214 	20231212
# 442900  미래에셋드림스팩1호     	20231219 	⭕
# 100790  미래에셋벤처투자       	20240219 	⭕
# 009900  명신산업           	⭕      	⭕
# 003650  미창석유공업         	⭕      	⭕
# 006800  미래에셋증권         	20240216 	20240201
# 080160  모두투어           	20240214 	20240126
# 333050  모코엠시스          	20240124 	20240123
# 002840  미원상사           	20231215 	20231215
# 009200  무림페이퍼          	20240205 	20240201
# 250060  모비스            	20240215 	⭕
# 049950  미래컴퍼니          	⭕      	⭕
# 417970  모델솔루션          	20240126 	20240108
# 085620  미래에셋생명         	20240213 	20240202
# 218150  미래생명자원         	20240118 	20240118
# 007120  미래아이앤지         	⭕      	⭕
# 314930  바이오다인          	20240214 	20240214
# 064550  바이오니아          	⭕      	⭕
# 382900  범한퓨얼셀          	20240118 	20240118
# 019010  베뉴지            	20240124 	20240124
# 206400  베노티앤알          	20231214 	⭕
# 002410  범양건영           	20231214 	20231211
# 066410  버킷스튜디오         	⭕      	⭕
# 046310  백금T&A          	20240214 	⭕
# 001340  백광산업           	⭕      	⭕
# 267790  배럴             	20240124 	⭕
# 438700  버넥트            	20231215 	⭕
# 043150  바텍             	⭕      	⭕
# 323990  박셀바이오          	⭕      	⭕
# 003610  방림             	20240111 	⭕
# 199730  바이오인프라         	⭕      	⭕
# 208710  바이오로그디바이스      	⭕      	⭕
# 032980  바이온            	20240105 	⭕
# 177350  베셀             	20240116 	20240108
# 299910  베스파            	⭕      	⭕
# 424760  벨로크            	20240124 	20240124
# 086820  바이오솔루션         	20240205 	20240205
# 035150  백산             	20240207 	20231222
# 038460  바이오스마트         	⭕      	⭕
# 251120  바이오에프디엔씨       	⭕      	⭕
# 086040  바이오톡스텍         	20240103 	20240102
# 099430  바이오플러스         	⭕      	⭕
# 308080  바이젠셀           	20240112 	20240111
# 331520  밸로프            	20240110 	⭕
# 044480  블레이드 Ent       	20231204 	20231204
# 337930  브랜드엑스코퍼레이션     	20240126 	20240126
# 121800  비덴트            	⭕      	⭕
# 369370  블리츠웨이          	20240125 	20231124
# 033560  블루콤            	20240118 	20240118
# 100120  뷰웍스            	20240124 	⭕
# 288330  브릿지바이오         	20240220 	20240220
# 018290  브이티            	20240214 	20240104
# 014470  부방             	20231128 	20231128
# 318410  비비씨            	20240207 	20240122
# 226340  본느             	⭕      	⭕
# 146320  비씨엔씨           	20240104 	20231220
# 008470  부스타            	⭕      	⭕
# 338220  뷰노             	20231124 	⭕
# 064480  브리지텍           	20240125 	20240125
# 090460  비에이치           	20240103 	⭕
# 005030  부산주공           	⭕      	⭕
# 200780  비씨월드제약         	20231207 	⭕
# 099390  브레인즈컴퍼니        	20240108 	⭕
# 230980  비유테크놀러지        	20240220 	20240220
# 086670  비엠티            	⭕      	⭕
# 439580  블루엠텍           	20231219 	20231213
# 335890  비올             	20231221 	20231201
# 001270  부국증권           	20240220 	20240205
# 310210  보로노이           	⭕      	⭕
# 000890  보해양조           	20231213 	⭕
# 082800  비보존 제약         	⭕      	⭕
# 452430  사피엔반도체         	20240220 	20240220
# 011390  부산산업           	20231129 	⭕
# 238200  비피도            	20240220 	20240220
# 251630  브이원텍           	20240111 	⭕
# 225530  보광산업           	⭕      	⭕
# 141000  비아트론           	⭕      	⭕
# 142760  비엘             	20240130 	⭕
# 082920  비츠로셀           	⭕      	⭕
# 006910  보성파워텍          	20231222 	20231212
# 100220  비상교육           	20240220 	20240220
# 003850  보령             	20240219 	20231214
# 003000  부광약품           	20240118 	20240116
# 148780  비플라이소프트        	20240219 	20240205
# 138580  비즈니스온          	20231226 	20231222
# 054220  비츠로시스          	20231221 	20231221
# 126340  비나텍            	20240124 	20240124
# 030790  비케이탑스          	⭕      	⭕
# 357880  비트나인           	20231220 	⭕
# 365900  브이씨            	20240105 	20240105
# 250000  보라티알           	⭕      	⭕
# 002760  보락             	20240115 	20231219
# 007210  벽산             	⭕      	⭕
# 002070  비비안            	⭕      	⭕
# 032850  비트컴퓨터          	20240219 	20240219
# 419540  비스토스           	⭕      	⭕
# 065450  빅텍             	20240118 	20240118
# 148140  비디아이           	⭕      	⭕
# 406820  뷰티스킨           	⭕      	⭕
# 445360  비엔케이제1호스팩      	⭕      	⭕
# 007160  사조산업           	20240220 	20240220
# 307870  비투엔            	⭕      	⭕
# 143240  사람인            	20240103 	20231220
# 003960  사조대림           	20240219 	20240201
# 050090  비케이홀딩스         	20231123 	20231123
# 210120  빅텐츠            	20240207 	20240117
# 065170  비엘팜텍           	20240131 	20240131
# 093190  빅솔론            	20240122 	20240122
# 072950  빛샘전자           	20240130 	20240116
# 014710  사조씨푸드          	⭕      	⭕
# 005180  빙그레            	⭕      	⭕
# 006090  사조오양           	20240118 	⭕
# 008040  사조동아원          	⭕      	⭕
# 026940  부국철강           	20240102 	20231214
# 083650  비에이치아이         	⭕      	⭕
# 122350  삼기             	⭕      	⭕
# 016360  삼성증권           	20240219 	20240216
# 068290  삼성출판사          	20240214 	20240206
# 000810  삼성화재해상보험       	20240214 	20240213
# 029780  삼성카드           	20240220 	20240220
# 005930  삼성전자           	20240119 	20240111
# 001360  삼성제약           	20240110 	20240108
# 028050  삼성엔지니어링        	20240131 	20240131
# 018260  삼성에스디에스        	20240111 	20240111
# 448740  삼성스팩8호         	⭕      	⭕
# 014970  삼륭물산           	20240123 	20240117
# 009620  삼보산업           	20240108 	20240105
# 006400  삼성SDI          	20240126 	⭕
# 419050  삼기이브이          	20240111 	20240111
# 419120  산돌             	20240219 	20240206
# 207940  삼성바이오로직스       	20240202 	20240129
# 028260  삼성물산           	20240220 	20240205
# 018310  삼목에스폼          	20240205 	⭕
# 006660  삼성공조           	20240206 	20240205
# 023600  삼보판지           	20240214 	20240206
# 001470  삼부토건           	⭕      	⭕
# 425290  삼성스팩6호         	⭕      	⭕
# 053700  삼보모터스          	20240215 	20240215
# 009150  삼성전기           	20231213 	20231128
# 010140  삼성중공업          	⭕      	⭕
# 439250  삼성스팩7호         	⭕      	⭕
# 042370  비츠로테크          	20240215 	⭕
# 032830  삼성생명           	20240219 	20240219
# 413640  비아이매트릭스        	20240108 	20240105
# 225190  삼양옵틱스          	⭕      	⭕
# 101000  상상인인더스트리       	⭕      	⭕
# 091580  상신이디피          	⭕      	⭕
# 415580  상상인제3호스팩       	20240124 	⭕
# 107600  새빗켐            	⭕      	⭕
# 294630  서남             	20240220 	20240220
# 006730  서부T&D          	20231128 	⭕
# 043710  서울리거           	20231204 	⭕
# 252990  샘씨엔에스          	20240214 	20240207
# 002450  삼익악기           	⭕      	⭕
# 042940  상지카일룸          	⭕      	⭕
# 263810  상신전자           	20240124 	20240124
# 038540  상상인            	20231214 	20231214
# 054090  삼진엘앤디          	20240109 	⭕
# 002290  삼일기업공사         	20240129 	20240129
# 009470  삼화전기           	20240124 	20240123
# 005500  삼진제약           	20240124 	20231208
# 038500  삼표시멘트          	20231214 	20231214
# 006110  삼아알미늄          	⭕      	⭕
# 017390  서울도시가스         	⭕      	⭕
# 001820  삼화콘덴서공업        	20231222 	⭕
# 011230  삼화전자공업         	20240124 	⭕
# 452670  상상인제4호스팩       	20240115 	20240115
# 019770  서연탑메탈          	20240213 	20240207
# 042600  새로닉스           	⭕      	⭕
# 092190  서울바이오시스        	⭕      	⭕
# 005680  삼영전자공업         	20240214 	20240202
# 054540  삼영엠텍           	20240104 	20240104
# 004380  삼익THK          	20240215 	20240214
# 100660  서암기계공업         	20240215 	20240213
# 046390  삼화네트웍스         	20240125 	20240125
# 007860  서연             	20240219 	20240213
# 003720  삼영             	⭕      	⭕
# 248170  샘표식품           	20240112 	⭕
# 272550  삼양패키징          	20240219 	20240202
# 200880  서연이화           	20240207 	20240207
# 038070  서린바이오          	20240219 	20240219
# 007540  샘표             	⭕      	⭕
# 075180  새론오토모티브        	20240125 	20240102
# 361670  삼영에스앤씨         	⭕      	⭕
# 378800  샤페론            	20240124 	⭕
# 089980  상아프론테크         	20240110 	20231221
# 017480  삼현철강           	20240130 	20240130
# 002810  삼영무역           	20240206 	20240205
# 027580  상보             	20240131 	20240131
# 000250  삼천당제약          	⭕      	⭕
# 001290  상상인증권          	20240214 	⭕
# 032280  삼일             	20240117 	20240115
# 003230  삼양식품           	20240201 	⭕
# 046890  서울반도체          	20240125 	20240122
# 004440  삼일씨엔에스         	20240115 	20240112
# 065570  삼영이엔씨          	⭕      	⭕
# 009770  삼정펄프           	20240206 	20240206
# 009300  삼아제약           	20231207 	⭕
# 000390  삼화페인트공업        	20240219 	20240216
# 002170  삼양통상           	20240206 	20240206
# 032750  삼진             	20240105 	⭕
# 145990  삼양사            	⭕      	⭕
# 000070  삼양홀딩스          	20240213 	20240205
# 041650  상신브레이크         	20240201 	20240201
# 037460  삼지전자           	20240201 	⭕
# 079650  서산             	⭕      	⭕
# 010960  삼호개발           	20240202 	20240201
# 023000  삼원강재           	⭕      	⭕
# 024950  삼천리자전거         	20240131 	20231123
# 411080  샌즈랩            	20240129 	20240124
# 000520  삼일제약           	20240219 	20240117
# 122690  서진오토모티브        	⭕      	⭕
# 018680  서울제약           	20240122 	20231207
# 003080  성보화학           	⭕      	⭕
# 011300  성안             	20231212 	20231212
# 081580  성우전자           	20240207 	⭕
# 037350  성도이엔지          	20240131 	⭕
# 021050  서원             	20240215 	⭕
# 027040  서울전자통신         	20231221 	20231221
# 086710  선진뷰티사이언스       	⭕      	⭕
# 357550  석경에이티          	⭕      	⭕
# 136490  선진             	20231222 	20231222
# 067370  선바이오           	⭕      	⭕
# 015750  성우하이텍          	20240202 	20240202
# 003100  선광             	⭕      	⭕
# 140070  서플러스글로벌        	20240207 	20240207
# 004410  서울식품공업         	20231220 	20231220
# 035890  서희건설           	⭕      	⭕
# 008490  서흥             	20231205 	⭕
# 178320  서진시스템          	20240214 	20240214
# 093920  서원인텍           	⭕      	⭕
# 011370  서한             	⭕      	⭕
# 189860  서전기전           	⭕      	⭕
# 045300  성우테크론          	20231213 	⭕
# 007610  선도전기           	⭕      	⭕
# 004690  삼천리            	20240201 	⭕
# 004450  삼화왕관           	20240131 	20240131
# 014910  성문전자           	20240108 	⭕
# 014620  성광벤드           	⭕      	⭕
# 171090  선익시스템          	⭕      	⭕
# 065710  서호전기           	20240213 	20231226
# 063170  서울옥션           	20240202 	20231213
# 340440  세림B&G          	⭕      	⭕
# 068270  셀트리온           	20240115 	20240103
# 108860  셀바스AI          	⭕      	⭕
# 003030  세아제강지주         	20231214 	20231214
# 075580  세진중공업          	20240125 	⭕
# 068940  셀피글로벌          	⭕      	⭕
# 304100  솔트룩스           	⭕      	⭕
# 004430  송원산업           	20231228 	⭕
# 306200  세아제강           	⭕      	⭕
# 248070  솔루엠            	⭕      	⭕
# 357780  솔브레인           	20240213 	20231201
# 067830  세이브존I&C        	20240220 	20240206
# 036830  솔브레인홀딩스        	20240220 	20240220
# 328380  솔트웨어           	⭕      	⭕
# 084180  수성샐바시온         	20240124 	⭕
# 268600  셀리버리           	⭕      	⭕
# 336370  솔루스첨단소재        	20240112 	20240108
# 091090  세원이앤씨          	⭕      	⭕
# 004490  세방전지           	20240214 	20240208
# 208370  셀바스헬스케어        	⭕      	⭕
# 252500  세화피앤씨          	⭕      	⭕
# 347000  센코             	20240131 	20240130
# 021820  세원정공           	20240216 	20240129
# 043100  솔고바이오          	20240220 	20240219
# 053450  세코닉스           	20240213 	20240213
# 036630  세종텔레콤          	20240126 	20240112
# 068760  셀트리온제약         	20240104 	20240103
# 066910  손오공            	20240103 	20240102
# 258830  세종메디칼          	20240205 	20240118
# 058650  세아홀딩스          	20240220 	20240130
# 321370  센서뷰            	20240111 	⭕
# 950200  소마젠            	20240109 	⭕
# 035610  솔본             	20240131 	20240131
# 039310  세중             	⭕      	⭕
# 318160  셀바이오휴먼텍        	⭕      	⭕
# 258790  소프트캠프          	20240119 	20240119
# 290690  소룩스            	20240206 	20231208
# 013000  세우글로벌          	⭕      	⭕
# 024830  세원물산           	⭕      	⭕
# 033530  세종공업           	20240214 	20240105
# 148150  세경하이테크         	20240220 	⭕
# 396300  세아메카닉스         	⭕      	⭕
# 002420  세기상사           	20240205 	⭕
# 049180  셀루메드           	20240104 	20240103
# 011560  세보엠이씨          	⭕      	⭕
# 004360  세방             	20240207 	⭕
# 100700  세운메디칼          	20240109 	20231204
# 331920  셀레믹스           	20240110 	20240110
# 222810  세토피아           	⭕      	⭕
# 126720  수산인더스트리        	⭕      	⭕
# 188260  세니젠            	⭕      	⭕
# 299660  셀리드            	20240111 	20240111
# 001430  세아베스틸지주        	20231127 	20231124
# 053060  세동             	⭕      	⭕
# 365340  성일하이텍          	⭕      	⭕
# 017510  세명전기           	20231127 	20231124
# 032680  소프트센           	20240216 	20240215
# 019440  세아특수강          	⭕      	⭕
# 080470  성창오토텍          	⭕      	⭕
# 000180  성창기업지주         	20240219 	20240131
# 017550  수산중공업          	⭕      	⭕
# 067770  세진티에스          	20231214 	20231213
# 050960  수산아이앤티         	⭕      	⭕
# 060230  소니드            	20231211 	⭕
# 086980  쇼박스            	20240115 	20231222
# 043260  성호전자           	⭕      	⭕
# 004980  성신양회           	20231124 	⭕
# 298830  슈어소프트테크        	⭕      	⭕
# 352090  스톰테크           	20231124 	20231123
# 192440  슈피겐코리아         	20240213 	20240202
# 134790  시디즈            	⭕      	⭕
# 000480  시알홀딩스          	⭕      	⭕
# 094840  슈프리마에이치큐       	20240126 	20240126
# 269620  시스웍            	⭕      	⭕
# 020710  시공테크           	20231130 	20231129
# 131090  시큐브            	⭕      	⭕
# 136510  스마트솔루션즈        	⭕      	⭕
# 236200  슈프리마           	20240201 	20240126
# 203690  스피어파워          	⭕      	⭕
# 026890  스틱인베스트먼트       	20240109 	⭕
# 415380  스튜디오삼익         	20240206 	20240206
# 424960  스마트레이더시스템      	⭕      	⭕
# 418250  시큐레터           	⭕      	⭕
# 204630  스튜디오산타클로스      	20240206 	⭕
# 049830  승일             	20231122 	20231122
# 099440  스맥             	20240112 	20231215
# 013810  스페코            	20240124 	20240119
# 330730  스톤브릿지벤처스       	20240109 	20240104
# 115570  스타플렉스          	20231127 	⭕
# 033790  스카이문스테크놀로지     	⭕      	⭕
# 159910  스킨앤스킨          	⭕      	⭕
# 048870  시너지이노베이션       	⭕      	⭕
# 429270  시지트로닉스         	⭕      	⭕
# 025320  시노펙스           	20240110 	20231222
# 033170  시그네틱스          	20240220 	20240220
# 253450  스튜디오드래곤        	⭕      	⭕
# 232830  시큐센            	⭕      	⭕
# 408900  스튜디오미르         	⭕      	⭕
# 276040  스코넥            	20240130 	20240129
# 017000  신원종합개발         	20240108 	20231129
# 243840  신흥에스이씨         	20231226 	20231226
# 217330  싸이토젠           	20240216 	20240130
# 222420  쎄노텍            	⭕      	⭕
# 065350  신성델타테크         	⭕      	⭕
# 088280  쏘닉스            	⭕      	⭕
# 005800  신영와코루          	20240131 	⭕
# 010280  쌍용정보통신         	20240131 	20240131
# 001720  신영증권           	20240219 	20240219
# 037760  쎄니트            	⭕      	⭕
# 004770  써니전자           	20231212 	20231212
# 066790  씨씨에스           	20240220 	20240220
# 403550  쏘카             	20231123 	⭕
# 049960  쎌바이오텍          	20240220 	20240206
# 004080  신흥             	20240206 	20240206
# 036710  심텍홀딩스          	20231228 	20231218
# 012790  신일제약           	20231221 	20231205
# 004970  신라교역           	20240202 	⭕
# 138070  신진에스엠          	20231130 	⭕
# 102280  쌍방울            	⭕      	⭕
# 019170  신풍제약           	20231205 	⭕
# 002870  신풍             	20240129 	20240111
# 002700  신일전자           	⭕      	⭕
# 222800  심텍             	20240102 	20231127
# 055550  신한지주           	20240219 	20240205
# 257720  실리콘투           	⭕      	⭕
# 418210  신한제10호스팩       	20240126 	20240126
# 031440  신세계푸드          	20240201 	20240201
# 056700  신화인터텍          	20240207 	20240126
# 006880  신송홀딩스          	20240119 	20240119
# 226330  신테카바이오         	⭕      	⭕
# 222080  씨아이에스          	20231130 	20231130
# 393360  신한제8호스팩        	20240219 	20231220
# 050890  쏠리드            	20240116 	20240115
# 187270  신화콘텍           	20240220 	20240220
# 208640  썸에이지           	20240122 	⭕
# 009270  신원             	20240109 	20240109
# 290560  신시웨이           	20231130 	20231130
# 035510  신세계I&C         	20240205 	20240131
# 419270  신영스팩7호         	20240219 	20240215
# 031430  신세계인터내셔날       	⭕      	⭕
# 290520  신도기연           	20231227 	⭕
# 016590  신대양제지          	20240201 	⭕
# 452980  신한제11호스팩       	⭕      	⭕
# 356890  싸이버원           	20240103 	⭕
# 099320  쎄트렉아이          	20240111 	20240103
# 029530  신도리코           	20240220 	20240220
# 162300  신스틸            	20240220 	20240131
# 109670  씨싸이트           	20231226 	20231222
# 416180  신성에스티          	20240215 	20240206
# 215600  신라젠            	20240214 	20231212
# 005390  신성통상           	20240202 	⭕
# 445970  신영스팩9호         	20240123 	20240112
# 002800  신신제약           	⭕      	⭕
# 011930  신성이엔지          	20240117 	⭕
# 004920  씨아이테크          	⭕      	⭕
# 001000  신라섬유           	⭕      	⭕
# 025870  신라에스지          	20240125 	⭕
# 160980  싸이맥스           	⭕      	⭕
# 034300  신세계건설          	20240123 	20240119
# ...
# 130740  티피씨글로벌         	20231222 	⭕
# 069260  티케이지휴켐스        	⭕      	⭕
# 441270  파인엠텍           	20240216 	20240216
# 177830  파버나인           	20231208 	⭕
# 026150  특수건설           	20240201 	20240130
# 058530  파나케이아          	⭕      	⭕
# 033540  파라텍            	20240220 	20240102
# 081150  티플랙스           	⭕      	⭕
# 091810  티웨이항공          	20240214 	20240115
# 440110  파두             	⭕      	⭕
# 322180  티라유텍           	⭕      	⭕
# 368770  파이버프로          	⭕      	⭕
# 104480  티케이케미칼         	20240117 	20240115
# 106240  파인테크닉스         	⭕      	⭕
# 131290  티에스이           	20240215 	20240213
# 079970  투비소프트          	20240219 	⭕
# 214420  토니모리           	20240112 	20240109
# 047310  파워로직스          	20240208 	⭕
# 051360  토비스            	20240201 	20231122
# 105550  트루윈            	20231221 	⭕
# 131100  티엔엔터테인먼트       	20231215 	20231214
# 204610  티쓰리            	⭕      	⭕
# 199800  툴젠             	20231215 	20231214
# 057680  티사이언티픽         	20240111 	20240111
# 045340  토탈소프트          	20240102 	20240102
# 277880  티에스아이          	⭕      	⭕
# 033830  티비씨            	20231227 	20231124
# 062860  티엘아이           	⭕      	⭕
# 425420  티에프이           	⭕      	⭕
# 038950  파인디지털          	20231218 	20231215
# 004870  티웨이홀딩스         	⭕      	⭕
# 150900  파수             	20240215 	⭕
# 037030  파워넷            	⭕      	⭕
# 034230  파라다이스          	⭕      	⭕
# 049120  파인디앤씨          	20240202 	20240116
# 246710  티앤알바이오팹        	20240110 	20231124
# 290720  푸드나무           	⭕      	⭕
# 032800  판타지오           	20240131 	20240122
# 027710  팜스토리           	⭕      	⭕
# 047050  포스코인터내셔널       	20231227 	⭕
# 318020  포인트모바일         	⭕      	⭕
# 114630  폴라리스우노         	20240105 	⭕
# 331380  포커스에이치엔에스      	⭕      	⭕
# 068050  팬엔터테인먼트        	20240110 	⭕
# 256630  포인트엔지니어링       	20240117 	20240111
# 090080  평화산업           	⭕      	⭕
# 189690  포시에스           	20240131 	20240119
# 009520  포스코엠텍          	⭕      	⭕
# 389140  포바이포           	20240219 	20240122
# 105760  포스뱅크           	20240129 	20240129
# 058430  포스코스틸리온        	20231227 	20231227
# 022100  포스코DX          	⭕      	⭕
# 041020  폴라리스오피스        	20240122 	20240108
# 087010  펩트론            	⭕      	⭕
# 140860  파크시스템스         	20240201 	20231211
# 010770  평화홀딩스          	⭕      	⭕
# 225590  패션플랫폼          	⭕      	⭕
# 222110  팬젠             	20231227 	20231218
# 001020  페이퍼코리아         	20231226 	20231226
# 091700  파트론            	⭕      	⭕
# 065690  파커스            	20240105 	20240105
# 016800  퍼시스            	20240220 	20240220
# 251970  펌텍코리아          	⭕      	⭕
# 004720  팜젠사이언스         	20231227 	20231226
# 318010  팜스빌            	20240213 	⭕
# 036580  팜스코            	20231220 	20231220
# 168360  펨트론            	⭕      	⭕
# 003670  포스코퓨처엠         	⭕      	⭕
# 234100  폴라리스세원         	20240122 	20240105
# 119500  포메탈            	20240131 	20240131
# 271830  팸텍             	20240208 	20240205
# 028670  팬오션            	20240216 	20240208
# 010820  퍼스텍            	20240117 	20240117
# 263750  펄어비스           	⭕      	⭕
# 054300  팬스타엔터프라이즈      	20240219 	20231205
# 131760  파인텍            	20231207 	20231207
# 405000  플라즈맵           	20240215 	20240215
# 057880  피에이치씨          	⭕      	⭕
# 023900  풍국주정           	20240213 	20240213
# 319660  피에스케이          	⭕      	⭕
# 417180  핑거스토리          	20240220 	20240220
# 347740  피엔케이피부임상연구센타   	20231127 	20231127
# 257370  피엔티엠에스         	⭕      	⭕
# 378340  필에너지           	20240108 	20240105
# 304840  피플바이오          	20240115 	20240110
# 075130  플랜티넷           	20240216 	20240123
# 291810  핀텔             	⭕      	⭕
# 347770  핌스             	20240202 	20240131
# 163730  핑거             	20231211 	20231205
# 237750  피앤씨테크          	20231124 	⭕
# 377220  프롬바이오          	20240214 	⭕
# 032580  피델릭스           	20231212 	20231212
# 087600  픽셀플러스          	20240125 	20240125
# 031980  피에스케이홀딩스       	20240213 	⭕
# 005670  푸드웰            	⭕      	⭕
# 002230  피에스텍           	⭕      	⭕
# 300080  플리토            	20240219 	20240129
# 051380  피씨디렉트          	20240119 	20231206
# 406760  하나금융21호스팩      	20240207 	⭕
# 237820  플레이디           	20240207 	20240207
# 103140  풍산             	20231205 	20231205
# 128660  피제이메탈          	⭕      	⭕
# 367000  플래티어           	20240122 	20240122
# 006140  피제이전자          	20231211 	⭕
# 023770  플레이위드          	20231201 	⭕
# 137400  피엔티            	⭕      	⭕
# 009810  플레이그램          	20240116 	⭕
# 062970  피피아이           	20240213 	20240208
# 239890  피엔에이치테크        	20240109 	⭕
# 376180  피코그램           	20231228 	⭕
# 454640  하나29호스팩        	⭕      	⭕
# 094940  푸른기술           	20240117 	20231123
# 371950  풍원정밀           	20240119 	20240118
# 093380  풍강             	20240202 	20240202
# 241820  피씨엘            	20240116 	20240112
# 321260  프로이천           	20240116 	20240116
# 005810  풍산홀딩스          	⭕      	⭕
# 950210  프레스티지바이오파마     	⭕      	⭕
# 334970  프레스티지바이오로직스    	20240130 	⭕
# 035200  프럼파스트          	20240205 	20240205
# 370090  퓨런티어           	20240131 	⭕
# 445180  퓨릿             	20240108 	⭕
# 147760  피엠티            	20240216 	20240202
# 161580  필옵틱스           	20240130 	⭕
# 454750  하나28호스팩        	⭕      	⭕
# 017810  풀무원            	⭕      	⭕
# 303360  프로티아           	20231123 	⭕
# 053610  프로텍            	⭕      	⭕
# 446750  하나26호스팩        	20240220 	20240220
# 220100  퓨쳐켐            	20231222 	⭕
# 335810  프리시젼바이오        	20240219 	20240219
# 053160  프리엠스           	20240201 	20240201
# 041590  플래스크           	20240216 	20240216
# 448370  하나27호스팩        	20240220 	⭕
# 043370  피에이치에이         	20240216 	20240216
# 007330  푸른저축은행         	20240219 	20240205
# 126700  하이비젼시스템        	20240214 	20240213
# 039130  하나투어           	20240207 	20240207
# 067310  하나마이크론         	⭕      	⭕
# 293480  하나제약           	20240206 	20240206
# 025540  한국단자공업         	20231215 	20231129
# 039340  한국경제TV         	20231221 	20231221
# 086790  하나금융지주         	20240219 	20240213
# 005430  한국공항           	20240214 	20240122
# 036460  한국가스공사         	20240220 	20240220
# 010040  한국내화           	⭕      	⭕
# 149980  하이로닉           	20240215 	⭕
# 034950  한국기업평가         	20240213 	20231226
# 256840  한국비엔씨          	20240207 	20240207
# 222980  한국맥널티          	20240119 	⭕
# 004590  한국가구           	20240206 	⭕
# 166090  하나머티리얼즈        	20240102 	⭕
# 000140  하이트진로홀딩스       	20240206 	20240205
# 066130  하츠             	20231206 	20231206
# 019490  하이트론씨스템즈       	20240215 	20240104
# 013030  하이록코리아         	⭕      	⭕
# 450050  하이제8호스팩        	⭕      	⭕
# 106190  하이텍팜           	20240219 	20240219
# 071050  한국금융지주         	20240216 	20240201
# 435620  하나금융25호스팩      	20240216 	20240115
# 106080  하이소닉           	20240119 	⭕
# 373200  하인크코리아         	20240216 	⭕
# 221840  하이즈항공          	20240213 	⭕
# 430230  하나금융24호스팩      	20240117 	20240117
# 400840  하이제7호스팩        	20240220 	20240216
# 299030  하나기술           	⭕      	⭕
# 352820  하이브            	20231206 	⭕
# 010100  한국무브넥스         	⭕      	⭕
# 003380  하림지주           	20231227 	20231221
# 101670  하이드로리튬         	20240220 	20240220
# 136480  하림             	20240207 	20231226
# 071090  하이스틸           	20240130 	20240130
# 004090  한국석유공업         	20240117 	20240116
# 365590  하이딥            	⭕      	⭕
# 418170  하나금융22호스팩      	20240220 	20240219
# 006200  한국전자홀딩스        	20240118 	20240111
# 101680  한국정밀기계         	20240111 	20240104
# 452190  한빛레이저          	20240108 	20240105
# 053590  한국테크놀로지        	⭕      	⭕
# 023350  한국종합기술         	20240110 	20240110
# 066980  한성크린텍          	20240214 	20240205
# 105630  한세실업           	20240214 	⭕
# 009240  한샘             	⭕      	⭕
# 020000  한섬             	20240207 	20240207
# 003680  한성기업           	⭕      	⭕
# 016450  한세예스24홀딩스      	20240202 	⭕
# 161390  한국타이어앤테크놀로지    	20240118 	20240118
# 032300  한국파마           	20231211 	20231208
# 452280  한선엔지니어링        	20231130 	20231127
# 015760  한국전력공사         	20240220 	20240220
# 053690  한미글로벌          	⭕      	⭕
# 047810  한국항공우주         	20240202 	20240103
# 002960  한국쉘석유          	20240208 	20231228
# 128940  한미약품           	20240116 	20240116
# 092460  한라IMS          	20231214 	⭕
# 000970  한국주철관공업        	20231219 	⭕
# 021650  한국큐빅           	20240202 	⭕
# 003350  한국화장품제조        	⭕      	⭕
# 123690  한국화장품          	⭕      	⭕
# 052600  한네트            	20240215 	20240215
# 002390  한독             	20240129 	20231123
# 458610  한국제12호스팩       	⭕      	⭕
# 011500  한농화성           	20240206 	⭕
# 024720  한국콜마홀딩스        	20240129 	20240111
# 007280  한국특강           	⭕      	⭕
# 008930  한미사이언스         	20240213 	20240125
# 037230  한국팩키지          	20240110 	20240110
# 027970  한국제지           	⭕      	⭕
# 042700  한미반도체          	20240208 	⭕
# 002200  한국수출포장공업       	20240110 	20240110
# 025550  한국선재           	20231204 	⭕
# 080720  한국유니온제약        	20240219 	20240131
# 053300  한국정보인증         	20240131 	20231204
# 000240  한국앤컴퍼니         	20240201 	20231218
# 256150  한독크린텍          	⭕      	⭕
# 017890  한국알콜           	⭕      	⭕
# 039740  한국정보공학         	⭕      	⭕
# 063570  한국전자금융         	20240105 	⭕
# 025770  한국정보통신         	20231206 	20231205
# 025890  한국주강           	⭕      	⭕
# 436610  한국제11호스팩       	⭕      	⭕
# 054040  한국컴퓨터          	20240220 	20240216
# 017960  한국카본           	⭕      	⭕
# 104700  한국철강           	20240130 	⭕
# 041460  한국전자인증         	20240216 	20240111
# 123890  한국자산신탁         	20240219 	20240214
# 070590  한솔인티큐브         	20240202 	20240201
# 034830  한국토지신탁         	⭕      	⭕
# 069640  한세엠케이          	20231219 	20231219
# 023760  한국캐피탈          	20240213 	20240125
# 114810  한솔아이원스         	20240220 	20240220
# 161890  한국콜마           	20231214 	⭕
# 009180  한솔로지스틱스        	20240124 	20240118
# 047080  한빛소프트          	20240131 	20240129
# 030520  한글과컴퓨터         	20240219 	20240216
# 000080  하이트진로          	⭕      	⭕
# 002320  한진             	20240207 	20240130
# 052690  한전기술           	20240124 	20240124
# 226440  한송네오텍          	⭕      	⭕
# 180640  한진칼            	20240214 	20231220
# 372910  한컴라이프케어        	20240117 	⭕
# 003480  한진중공업홀딩스       	⭕      	⭕
# 009460  한창제지           	20240110 	20240110
# 002680  한탑             	⭕      	⭕
# 130660  한전산업           	⭕      	⭕
# 007770  한일화학           	⭕      	⭕
# 018880  한온시스템          	⭕      	⭕
# 079170  한창산업           	⭕      	⭕
# 003300  한일홀딩스          	20240219 	20240213
# 123840  한일진공           	20240126 	20240115
# 054920  한컴위드           	20240123 	20240122
# 002220  한일철강           	20240130 	20240130
# 024740  한일단조           	20240118 	20240117
# 005860  한일사료           	20240118 	⭕
# 010420  한솔피엔에스         	20240116 	⭕
# 025750  한솔홈데코          	20231123 	20231122
# 045100  한양이엔지          	⭕      	⭕
# 009420  한올바이오파마        	20231227 	20231227
# 014130  한익스프레스         	20240115 	20231222
# 300720  한일시멘트          	20240205 	⭕
# 014680  한솔케미칼          	20231130 	⭕
# 078350  한양디지텍          	20240215 	20240104
# 430690  한싹             	20231123 	⭕
# 198940  한주라이트메탈        	⭕      	⭕
# 004960  한신공영           	20240201 	⭕
# 000880  한화             	20240207 	20240202
# 213500  한솔제지           	20240201 	20240201
# 042520  한스바이오메드        	⭕      	⭕
# 011700  한신기계공업         	20231207 	⭕
# 005110  한창             	20231213 	20231213
# 051600  한전KPS          	20240220 	20240219
# 006390  한일현대시멘트        	20240205 	⭕
# 001750  한양증권           	20240220 	20240219
# 004710  한솔테크닉스         	⭕      	⭕
# 004150  한솔홀딩스          	20240219 	20240206
# 272210  한화시스템          	20240110 	20240103
# 088350  한화생명           	20240214 	20240205
# 009830  한화솔루션          	20231220 	20231220
# 452260  한화갤러리아         	20240220 	20240220
# 460930  현대힘스           	20240205 	20240205
# 057050  현대홈쇼핑          	20240215 	20240130
# 138360  협진             	20240208 	20240208
# 011080  형지I&C          	⭕      	⭕
# 001450  현대해상           	20240202 	⭕
# 090850  현대이지웰          	20240207 	20240119
# 111110  호전실업           	⭕      	⭕
# 064350  현대로템           	⭕      	⭕
# 011760  현대코퍼레이션        	⭕      	⭕
# 048410  현대바이오          	⭕      	⭕
# 052260  현대바이오랜드        	⭕      	⭕
# 017800  현대엘리베이터        	⭕      	⭕
# 319400  현대무벡스          	⭕      	⭕
# 005440  현대지에프홀딩스       	20240219 	20240207
# 004560  현대비앤지스틸        	20240123 	20240110
# 004020  현대제철           	20240129 	⭕
# 004310  현대약품           	20231128 	20231128
# 039010  현대에이치티         	20240122 	20240116
# 011210  현대위아           	20240202 	⭕
# 010620  현대미포조선         	20240213 	20240213
# 012330  현대모비스          	20240219 	20240202
# 234340  헥토파이낸셜         	20240215 	20240215
# 220180  핸디소프트          	20240102 	20231220
# 227840  현대코퍼레이션홀딩스     	⭕      	⭕
# 126560  현대퓨처넷          	20231212 	⭕
# 092300  현우산업           	20240116 	20240102
# 000720  현대건설           	20240131 	⭕
# 900270  헝셩그룹           	20240201 	20240125
# 003530  한화투자증권         	20240219 	20240215
# 042660  한화오션           	20231215 	20231129
# 001500  현대차증권          	20240219 	20240213
# 430460  한화플러스제3호스팩     	20231228 	20231222
# 076610  해성옵틱스          	⭕      	⭕
# 307950  현대오토에버         	20240130 	20240129
# 034810  해성산업           	20231211 	20231211
# 101530  해태제과식품         	20240214 	20240202
# 041440  현대에버다임         	20240219 	20240219
# 453340  현대그린푸드         	20240208 	⭕
# 093240  형지엘리트          	20240102 	⭕
# 214180  헥토이노베이션        	20231226 	20231208
# 195870  해성디에스          	20240102 	⭕
# 059270  해성티피씨          	20240112 	⭕
# 084990  헬릭스미스          	20240208 	20240206
# 086280  현대글로비스         	20240202 	20240201
# 000370  한화손해보험         	20240219 	20240214
# 003010  혜인             	20231215 	20231215
# 455310  한화플러스제4호스팩     	⭕      	⭕
# 012450  한화에어로스페이스      	20231201 	⭕
# 008770  호텔신라           	⭕      	⭕
# 143210  핸즈코퍼레이션        	20240119 	20231127
# 005380  현대자동차          	20240220 	20240208
# 060560  홈센타홀딩스         	20231128 	20231128
# 079430  현대리바트          	20240125 	20240125
# 069960  현대백화점          	20240208 	20240208
# 386580  한화플러스제2호스팩     	20231127 	20231127
# 094280  효성 ITX         	⭕      	⭕
# 133820  화인베스틸          	20240105 	20240105
# 241590  화승엔터프라이즈       	20240126 	20240126
# 200670  휴메딕스           	20240119 	⭕
# 298050  효성첨단소재         	20231226 	20231226
# 115160  휴맥스            	20240201 	⭕
# 028080  휴맥스홀딩스         	⭕      	⭕
# 205470  휴마시스           	⭕      	⭕
# 079980  휴비스            	⭕      	⭕
# 078590  휴림에이텍          	20240122 	20240122
# 378850  화승알앤에이         	20240208 	20240206
# 353190  휴럼             	20240220 	⭕
# 290270  휴네시온           	20240115 	20240110
# 005870  휴니드테크놀러지스      	20240118 	20240117
# 005010  휴스틸            	20240205 	20240202
# 002460  화성산업           	20240216 	20240216
# 010690  화신             	20240202 	20240202
# 298020  효성티앤씨          	⭕      	⭕
# 081660  휠라홀딩스          	20231220 	⭕
# 215090  휴센텍            	⭕      	⭕
# 004800  효성             	20240201 	20231227
# 263920  휴엠앤씨           	⭕      	⭕
# 039610  화성밸브           	⭕      	⭕
# 013520  화승코퍼레이션        	20240205 	20231122
# 097870  효성오앤비          	20240103 	20231208
# 032560  황금에스티          	⭕      	⭕
# 298040  효성중공업          	20240220 	20231214
# 192410  휴림네트웍스         	20240220 	20240220
# 127980  화인써키트          	20240124 	20231213
# 000850  화천기공           	20240213 	⭕
# 006060  화승인더스트리        	20240205 	⭕
# 065510  휴비츠            	20240205 	20240205
# 016580  환인제약           	20231206 	20231206
# 010660  화천기계           	20240213 	⭕
# 170030  현대공업           	20240115 	20240115
# 090710  휴림로봇           	20240119 	⭕
# 093370  후성             	⭕      	⭕
# 298000  효성화학           	20240131 	⭕
# 126640  화신정공           	⭕      	⭕
# 064240  홈캐스트           	20231201 	20231130
# 061250  화일약품           	20240129 	20231208
# 238490  힘스             	20240125 	⭕
# 010240  흥국             	20240118 	⭕
# 037440  희림             	20231128 	⭕
# 243070  휴온스            	20240214 	20231123
# 000540  흥국화재           	20240220 	20240215
# 189980  흥국에프엔비         	20240131 	20240124
# 145020  휴젤             	⭕      	⭕
# 024060  흥구석유           	20240116 	20240109
# 003280  흥아해운           	20240117 	20240117
# 084110  휴온스글로벌         	20240215 	20240214
